# %%
import cv2
from darkflow.net.build import TFNet
import matplotlib.pyplot as plt
# %config InlineBackend.figure_format = 'svg'
import tensorflow as tf
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0711 14:02:50.811094 4730979776 deprecation_wrapper.py:119] From /Users/kevin.nguyen/Projects/darkflow/darkflow/net/build.py:15: The name tf.train.RMSPropOptimizer is deprecated. Please use tf.compat.v1.train.RMSPropOptimizer instead.
#
# W0711 14:02:50.811923 4730979776 deprecation_wrapper.py:119] From /Users/kevin.nguyen/Projects/darkflow/darkflow/net/build.py:16: The name tf.train.AdadeltaOptimizer is deprecated. Please use tf.compat.v1.train.AdadeltaOptimizer instead.
#
# W0711 14:02:50.812448 4730979776 deprecation_wrapper.py:119] From /Users/kevin.nguyen/Projects/darkflow/darkflow/net/build.py:17: The name tf.train.AdagradOptimizer is deprecated. Please use tf.compat.v1.train.AdagradOptimizer instead.
#
# W0711 14:02:50.812971 4730979776 deprecation_wrapper.py:119] From /Users/kevin.nguyen/Projects/darkflow/darkflow/net/build.py:18: The name tf.train.AdagradDAOptimizer is deprecated. Please use tf.compat.v1.train.AdagradDAOptimizer instead.
#
# W0711 14:02:50.813549 4730979776 deprecation_wrapper.py:119] From /Users/kevin.nguyen/Projects/darkflow/darkflow/net/build.py:19: The name tf.train.MomentumOptimizer is deprecated. Please use tf.compat.v1.train.MomentumOptimizer instead.

# %%
options = {
    "model":"cfg/yolov2-voc-1c.cfg",
    "load":"bin/yolov2-voc.weights",
    "epoch":1000,
    "train":True,
    "annotation":"train/annotations/",
    "dataset":"train/images/"
}

# %%
tfnet = TFNet(options)
# Out:
# Parsing ./cfg/yolov2-voc.cfg
# Parsing cfg/yolov2-voc-1c.cfg
# Loading bin/yolov2-voc.weights ...
# W0711 15:11:36.924798 4574217664 deprecation_wrapper.py:119] From /Users/kevin.nguyen/Projects/darkflow/darkflow/net/build.py:105: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0711 15:11:36.928891 4574217664 deprecation_wrapper.py:119] From /Users/kevin.nguyen/Projects/darkflow/darkflow/net/ops/baseop.py:70: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# W0711 15:11:36.930227 4574217664 deprecation_wrapper.py:119] From /Users/kevin.nguyen/Projects/darkflow/darkflow/net/ops/baseop.py:71: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# W0711 15:11:36.939121 4574217664 deprecation_wrapper.py:119] From /Users/kevin.nguyen/Projects/darkflow/darkflow/net/ops/baseop.py:84: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# W0711 15:11:37.000087 4574217664 deprecation_wrapper.py:119] From /Users/kevin.nguyen/Projects/darkflow/darkflow/net/ops/simple.py:106: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
# Successfully identified 202704264 bytes
# Finished in 0.7685589790344238s
#
# Building net ...
# Source | Train? | Layer description                | Output size
# -------+--------+----------------------------------+---------------
#        |        | input                            | (?, 416, 416, 3)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 416, 416, 32)
#  Load  |  Yep!  | maxp 2x2p0_2                     | (?, 208, 208, 32)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 208, 208, 64)
#  Load  |  Yep!  | maxp 2x2p0_2                     | (?, 104, 104, 64)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 104, 104, 128)
#  Load  |  Yep!  | conv 1x1p0_1  +bnorm  leaky      | (?, 104, 104, 64)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 104, 104, 128)
#  Load  |  Yep!  | maxp 2x2p0_2                     | (?, 52, 52, 128)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 52, 52, 256)
#  Load  |  Yep!  | conv 1x1p0_1  +bnorm  leaky      | (?, 52, 52, 128)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 52, 52, 256)
#  Load  |  Yep!  | maxp 2x2p0_2                     | (?, 26, 26, 256)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 26, 26, 512)
#  Load  |  Yep!  | conv 1x1p0_1  +bnorm  leaky      | (?, 26, 26, 256)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 26, 26, 512)
#  Load  |  Yep!  | conv 1x1p0_1  +bnorm  leaky      | (?, 26, 26, 256)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 26, 26, 512)
#  Load  |  Yep!  | maxp 2x2p0_2                     | (?, 13, 13, 512)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 13, 13, 1024)
#  Load  |  Yep!  | conv 1x1p0_1  +bnorm  leaky      | (?, 13, 13, 512)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 13, 13, 1024)
#  Load  |  Yep!  | conv 1x1p0_1  +bnorm  leaky      | (?, 13, 13, 512)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 13, 13, 1024)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 13, 13, 1024)
# W0711 15:11:39.376096 4574217664 deprecation.py:506] From /Users/kevin.nguyen/Projects/darkflow/darkflow/net/ops/convolution.py:28: calling extract_image_patches (from tensorflow.python.ops.array_ops) with ksizes is deprecated and will be removed in a future version.
# Instructions for updating:
# ksizes is deprecated, use sizes instead
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 13, 13, 1024)
#  Load  |  Yep!  | concat [16]                      | (?, 26, 26, 512)
#  Load  |  Yep!  | conv 1x1p0_1  +bnorm  leaky      | (?, 26, 26, 64)
#  Load  |  Yep!  | local flatten 2x2                | (?, 13, 13, 256)
#  Load  |  Yep!  | concat [27, 24]                  | (?, 13, 13, 1280)
# W0711 15:11:39.964797 4574217664 deprecation.py:323] From /Users/kevin.nguyen/Projects/darkflow/darkflow/net/yolov2/train.py:87: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0711 15:11:39.984498 4574217664 deprecation_wrapper.py:119] From /Users/kevin.nguyen/Projects/darkflow/darkflow/net/yolov2/train.py:107: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# W0711 15:11:40.042819 4574217664 deprecation.py:323] From /anaconda3/envs/tfdeeplearning/lib/python3.5/site-packages/tensorflow/python/ops/math_grad.py:1205: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 13, 13, 1024)
#  Init  |  Yep!  | conv 1x1p0_1    linear           | (?, 13, 13, 30)
# -------+--------+----------------------------------+---------------
# Running entirely on CPU
# cfg/yolov2-voc-1c.cfg loss hyper-parameters:
# 	H       = 13
# 	W       = 13
# 	box     = 5
# 	classes = 1
# 	scales  = [1.0, 5.0, 1.0, 1.0]
# Building cfg/yolov2-voc-1c.cfg loss
# Building cfg/yolov2-voc-1c.cfg train op
# W0711 15:11:41.573026 4574217664 deprecation.py:506] From /anaconda3/envs/tfdeeplearning/lib/python3.5/site-packages/tensorflow/python/training/rmsprop.py:119: calling Ones.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# W0711 15:11:42.092786 4574217664 deprecation_wrapper.py:119] From /Users/kevin.nguyen/Projects/darkflow/darkflow/net/build.py:145: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
# Finished in 13.355182886123657s

# %%
# %%time
tfnet.train()
# Out:
# cfg/yolov2-voc-1c.cfg parsing train/annotations/
# Parsing for ['arrow']
# [====================>]100%  000003.xml
# Statistics:
# arrow: 555
# Dataset size: 30
# Dataset of 30 instance(s)
# Training statistics:
# 	Learning rate : 1e-05
# 	Batch size    : 16
# 	Epoch number  : 1000
# 	Backup every  : 2000
# step 1 - loss 115.63676452636719 - moving ave loss 115.63676452636719
# Finish 1 epoch(es)
# step 2 - loss 114.9269027709961 - moving ave loss 115.56577835083009
# Finish 2 epoch(es)
# step 3 - loss 113.38455200195312 - moving ave loss 115.3476557159424
# Finish 3 epoch(es)
# step 4 - loss 111.88472747802734 - moving ave loss 115.0013628921509
# Finish 4 epoch(es)
# step 5 - loss 109.80146789550781 - moving ave loss 114.48137339248659
# Finish 5 epoch(es)
# step 6 - loss 111.91157531738281 - moving ave loss 114.22439358497621
# Finish 6 epoch(es)
# step 7 - loss 110.78146362304688 - moving ave loss 113.88010058878329
# Finish 7 epoch(es)
# step 8 - loss 108.72814178466797 - moving ave loss 113.36490470837177
# Finish 8 epoch(es)
# step 9 - loss 111.61605834960938 - moving ave loss 113.19002007249553
# Finish 9 epoch(es)
# step 10 - loss 110.02534484863281 - moving ave loss 112.87355255010925
# Finish 10 epoch(es)
# step 11 - loss 107.2160873413086 - moving ave loss 112.3078060292292
# Finish 11 epoch(es)
# step 12 - loss 107.77091217041016 - moving ave loss 111.8541166433473
# Finish 12 epoch(es)
# step 13 - loss 105.97880554199219 - moving ave loss 111.2665855332118
# Finish 13 epoch(es)
# step 14 - loss 108.06461334228516 - moving ave loss 110.94638831411913
# Finish 14 epoch(es)
# step 15 - loss 106.37133026123047 - moving ave loss 110.48888250883027
# Finish 15 epoch(es)
# step 16 - loss 104.93034362792969 - moving ave loss 109.93302862074022
# Finish 16 epoch(es)
# step 17 - loss 103.58003234863281 - moving ave loss 109.29772899352949
# Finish 17 epoch(es)
# step 18 - loss 104.27983093261719 - moving ave loss 108.79593918743826
# Finish 18 epoch(es)
# step 19 - loss 104.64041137695312 - moving ave loss 108.38038640638976
# Finish 19 epoch(es)
# step 20 - loss 102.85039520263672 - moving ave loss 107.82738728601447
# Finish 20 epoch(es)
# step 21 - loss 100.34268188476562 - moving ave loss 107.07891674588959
# Finish 21 epoch(es)
# step 22 - loss 103.09292602539062 - moving ave loss 106.6803176738397
# Finish 22 epoch(es)
# step 23 - loss 102.07109832763672 - moving ave loss 106.21939573921941
# Finish 23 epoch(es)
# step 24 - loss 99.11666870117188 - moving ave loss 105.50912303541466
# Finish 24 epoch(es)
# step 25 - loss 100.96092224121094 - moving ave loss 105.05430295599429
# Finish 25 epoch(es)
# step 26 - loss 100.66897583007812 - moving ave loss 104.61577024340268
# Finish 26 epoch(es)
# step 27 - loss 99.97052001953125 - moving ave loss 104.15124522101553
# Finish 27 epoch(es)
# step 28 - loss 97.78358459472656 - moving ave loss 103.51447915838664
# Finish 28 epoch(es)
# step 29 - loss 101.0352783203125 - moving ave loss 103.26655907457922
# Finish 29 epoch(es)
# step 30 - loss 98.26249694824219 - moving ave loss 102.76615286194553
# Finish 30 epoch(es)
# step 31 - loss 98.31788635253906 - moving ave loss 102.32132621100487
# Finish 31 epoch(es)
# step 32 - loss 97.17567443847656 - moving ave loss 101.80676103375204
# Finish 32 epoch(es)
# step 33 - loss 97.15808868408203 - moving ave loss 101.34189379878504
# Finish 33 epoch(es)
# step 34 - loss 97.1630859375 - moving ave loss 100.92401301265653
# Finish 34 epoch(es)
# step 35 - loss 95.82894134521484 - moving ave loss 100.41450584591236
# Finish 35 epoch(es)
# step 36 - loss 95.4301986694336 - moving ave loss 99.91607512826448
# Finish 36 epoch(es)
# step 37 - loss 95.07394409179688 - moving ave loss 99.43186202461771
# Finish 37 epoch(es)
# step 38 - loss 94.09347534179688 - moving ave loss 98.89802335633563
# Finish 38 epoch(es)
# step 39 - loss 95.93344116210938 - moving ave loss 98.60156513691301
# Finish 39 epoch(es)
# step 40 - loss 94.4746322631836 - moving ave loss 98.18887184954008
# Finish 40 epoch(es)
# step 41 - loss 94.09407043457031 - moving ave loss 97.77939170804311
# Finish 41 epoch(es)
# step 42 - loss 94.32798767089844 - moving ave loss 97.43425130432865
# Finish 42 epoch(es)
# step 43 - loss 92.39647674560547 - moving ave loss 96.93047384845633
# Finish 43 epoch(es)
# step 44 - loss 91.75480651855469 - moving ave loss 96.41290711546617
# Finish 44 epoch(es)
# step 45 - loss 91.87442016601562 - moving ave loss 95.95905842052112
# Finish 45 epoch(es)
# step 46 - loss 91.04683685302734 - moving ave loss 95.46783626377174
# Finish 46 epoch(es)
# step 47 - loss 91.01190185546875 - moving ave loss 95.02224282294144
# Finish 47 epoch(es)
# step 48 - loss 91.30279541015625 - moving ave loss 94.65029808166292
# Finish 48 epoch(es)
# step 49 - loss 90.44554138183594 - moving ave loss 94.22982241168023
# Finish 49 epoch(es)
# step 50 - loss 88.2200927734375 - moving ave loss 93.62884944785597
# Finish 50 epoch(es)
# step 51 - loss 92.62577819824219 - moving ave loss 93.5285423228946
# Finish 51 epoch(es)
# step 52 - loss 89.08160400390625 - moving ave loss 93.08384849099576
# Finish 52 epoch(es)
# step 53 - loss 87.72309875488281 - moving ave loss 92.54777351738447
# Finish 53 epoch(es)
# step 54 - loss 89.06652069091797 - moving ave loss 92.19964823473782
# Finish 54 epoch(es)
# step 55 - loss 88.1141357421875 - moving ave loss 91.7910969854828
# Finish 55 epoch(es)
# step 56 - loss 85.04356384277344 - moving ave loss 91.11634367121187
# Finish 56 epoch(es)
# step 57 - loss 88.02466583251953 - moving ave loss 90.80717588734264
# Finish 57 epoch(es)
# step 58 - loss 88.02428436279297 - moving ave loss 90.52888673488768
# Finish 58 epoch(es)
# step 59 - loss 84.24589538574219 - moving ave loss 89.90058759997314
# Finish 59 epoch(es)
# step 60 - loss 84.5230941772461 - moving ave loss 89.36283825770043
# Finish 60 epoch(es)
# step 61 - loss 82.30581665039062 - moving ave loss 88.65713609696945
# Finish 61 epoch(es)
# step 62 - loss 82.84663391113281 - moving ave loss 88.0760858783858
# Finish 62 epoch(es)
# step 63 - loss 86.58039093017578 - moving ave loss 87.9265163835648
# Finish 63 epoch(es)
# step 64 - loss 82.05133819580078 - moving ave loss 87.33899856478841
# Finish 64 epoch(es)
# step 65 - loss 86.46746826171875 - moving ave loss 87.25184553448145
# Finish 65 epoch(es)
# step 66 - loss 79.76136779785156 - moving ave loss 86.50279776081845
# Finish 66 epoch(es)
# step 67 - loss 83.29409790039062 - moving ave loss 86.18192777477567
# Finish 67 epoch(es)
# step 68 - loss 82.969482421875 - moving ave loss 85.86068323948561
# Finish 68 epoch(es)
# step 69 - loss 79.65198516845703 - moving ave loss 85.23981343238276
# Finish 69 epoch(es)
# step 70 - loss 83.36178588867188 - moving ave loss 85.05201067801167
# Finish 70 epoch(es)
# step 71 - loss 78.10206604003906 - moving ave loss 84.35701621421441
# Finish 71 epoch(es)
# step 72 - loss 78.94190979003906 - moving ave loss 83.81550557179688
# Finish 72 epoch(es)
# step 73 - loss 79.2317886352539 - moving ave loss 83.35713387814259
# Finish 73 epoch(es)
# step 74 - loss 77.41830444335938 - moving ave loss 82.76325093466427
# Finish 74 epoch(es)
# step 75 - loss 78.59808349609375 - moving ave loss 82.34673419080723
# Finish 75 epoch(es)
# step 76 - loss 79.2113265991211 - moving ave loss 82.03319343163861
# Finish 76 epoch(es)
# step 77 - loss 75.30240631103516 - moving ave loss 81.36011471957826
# Finish 77 epoch(es)
# step 78 - loss 75.28569030761719 - moving ave loss 80.75267227838215
# Finish 78 epoch(es)
# step 79 - loss 74.3783187866211 - moving ave loss 80.11523692920605
# Finish 79 epoch(es)
# step 80 - loss 76.5478286743164 - moving ave loss 79.75849610371708
# Finish 80 epoch(es)
# step 81 - loss 76.18309783935547 - moving ave loss 79.40095627728091
# Finish 81 epoch(es)
# step 82 - loss 73.79814147949219 - moving ave loss 78.84067479750205
# Finish 82 epoch(es)
# step 83 - loss 73.43760681152344 - moving ave loss 78.30036799890419
# Finish 83 epoch(es)
# step 84 - loss 73.26998901367188 - moving ave loss 77.79733010038096
# Finish 84 epoch(es)
# step 85 - loss 75.65440368652344 - moving ave loss 77.58303745899521
# Finish 85 epoch(es)
# step 86 - loss 71.79302215576172 - moving ave loss 77.00403592867185
# Finish 86 epoch(es)
# step 87 - loss 72.56118774414062 - moving ave loss 76.55975111021873
# Finish 87 epoch(es)
# step 88 - loss 69.28770446777344 - moving ave loss 75.8325464459742
# Finish 88 epoch(es)
# step 89 - loss 71.27571105957031 - moving ave loss 75.37686290733382
# Finish 89 epoch(es)
# step 90 - loss 70.25064086914062 - moving ave loss 74.8642407035145
# Finish 90 epoch(es)
# step 91 - loss 69.06430053710938 - moving ave loss 74.28424668687398
# Finish 91 epoch(es)
# step 92 - loss 67.66581726074219 - moving ave loss 73.62240374426081
# Finish 92 epoch(es)
# step 93 - loss 67.32445526123047 - moving ave loss 72.99260889595777
# Finish 93 epoch(es)
# step 94 - loss 67.41844177246094 - moving ave loss 72.4351921836081
# Finish 94 epoch(es)
# step 95 - loss 67.46084594726562 - moving ave loss 71.93775755997386
# Finish 95 epoch(es)
# step 96 - loss 67.2218017578125 - moving ave loss 71.46616197975773
# Finish 96 epoch(es)
# step 97 - loss 65.66152954101562 - moving ave loss 70.88569873588352
# Finish 97 epoch(es)
# step 98 - loss 67.03182220458984 - moving ave loss 70.50031108275417
# Finish 98 epoch(es)
# step 99 - loss 65.22640991210938 - moving ave loss 69.9729209656897
# Finish 99 epoch(es)
# step 100 - loss 64.38138580322266 - moving ave loss 69.41376744944299
# Finish 100 epoch(es)
# step 101 - loss 64.79011535644531 - moving ave loss 68.95140224014321
# Finish 101 epoch(es)
# step 102 - loss 62.452030181884766 - moving ave loss 68.30146503431737
# Finish 102 epoch(es)
# step 103 - loss 65.3527603149414 - moving ave loss 68.00659456237977
# Finish 103 epoch(es)
# step 104 - loss 63.348419189453125 - moving ave loss 67.54077702508711
# Finish 104 epoch(es)
# step 105 - loss 63.56458282470703 - moving ave loss 67.1431576050491
# Finish 105 epoch(es)
# step 106 - loss 62.18958282470703 - moving ave loss 66.64780012701489
# Finish 106 epoch(es)
# step 107 - loss 60.06877899169922 - moving ave loss 65.98989801348333
# Finish 107 epoch(es)
# step 108 - loss 60.7373046875 - moving ave loss 65.464638680885
# Finish 108 epoch(es)
# step 109 - loss 59.604007720947266 - moving ave loss 64.87857558489122
# Finish 109 epoch(es)
# step 110 - loss 61.76579284667969 - moving ave loss 64.56729731107008
# Finish 110 epoch(es)
# step 111 - loss 60.003753662109375 - moving ave loss 64.110942946174
# Finish 111 epoch(es)
# step 112 - loss 61.512489318847656 - moving ave loss 63.85109758344137
# Finish 112 epoch(es)
# step 113 - loss 58.49458694458008 - moving ave loss 63.315446519555245
# Finish 113 epoch(es)
# step 114 - loss 60.13606262207031 - moving ave loss 62.997508129806754
# Finish 114 epoch(es)
# step 115 - loss 60.132545471191406 - moving ave loss 62.71101186394522
# Finish 115 epoch(es)
# step 116 - loss 59.26168441772461 - moving ave loss 62.36607911932316
# Finish 116 epoch(es)
# step 117 - loss 55.69525909423828 - moving ave loss 61.698997116814674
# Finish 117 epoch(es)
# step 118 - loss 55.82329559326172 - moving ave loss 61.11142696445938
# Finish 118 epoch(es)
# step 119 - loss 54.51090621948242 - moving ave loss 60.451374889961684
# Finish 119 epoch(es)
# step 120 - loss 55.37782287597656 - moving ave loss 59.94401968856317
# Finish 120 epoch(es)
# step 121 - loss 56.62030029296875 - moving ave loss 59.61164774900374
# Finish 121 epoch(es)
# step 122 - loss 55.31922912597656 - moving ave loss 59.18240588670102
# Finish 122 epoch(es)
# step 123 - loss 51.685829162597656 - moving ave loss 58.43274821429068
# Finish 123 epoch(es)
# step 124 - loss 53.97296905517578 - moving ave loss 57.98677029837919
# Finish 124 epoch(es)
# step 125 - loss 50.66009521484375 - moving ave loss 57.25410279002565
# Checkpoint at step 125
# Finish 125 epoch(es)
# step 126 - loss 53.200439453125 - moving ave loss 56.84873645633558
# Finish 126 epoch(es)
# step 127 - loss 53.86444854736328 - moving ave loss 56.55030766543835
# Finish 127 epoch(es)
# step 128 - loss 50.72566223144531 - moving ave loss 55.967843122039056
# Finish 128 epoch(es)
# step 129 - loss 49.41705322265625 - moving ave loss 55.31276413210078
# Finish 129 epoch(es)
# step 130 - loss 48.71652603149414 - moving ave loss 54.653140322040116
# Finish 130 epoch(es)
# step 131 - loss 49.703269958496094 - moving ave loss 54.158153285685714
# Finish 131 epoch(es)
# step 132 - loss 47.99394226074219 - moving ave loss 53.541732183191364
# Finish 132 epoch(es)
# step 133 - loss 49.009544372558594 - moving ave loss 53.08851340212809
# Finish 133 epoch(es)
# step 134 - loss 49.24346160888672 - moving ave loss 52.70400822280396
# Finish 134 epoch(es)
# step 135 - loss 47.94171905517578 - moving ave loss 52.22777930604114
# Finish 135 epoch(es)
# step 136 - loss 47.12540054321289 - moving ave loss 51.71754142975832
# Finish 136 epoch(es)
# step 137 - loss 47.589988708496094 - moving ave loss 51.3047861576321
# Finish 137 epoch(es)
# step 138 - loss 45.39567947387695 - moving ave loss 50.71387548925659
# Finish 138 epoch(es)
# step 139 - loss 44.618736267089844 - moving ave loss 50.104361567039916
# Finish 139 epoch(es)
# step 140 - loss 47.65058898925781 - moving ave loss 49.85898430926171
# Finish 140 epoch(es)
# step 141 - loss 44.96760559082031 - moving ave loss 49.36984643741757
# Finish 141 epoch(es)
# step 142 - loss 44.471675872802734 - moving ave loss 48.88002938095609
# Finish 142 epoch(es)
# step 143 - loss 42.682029724121094 - moving ave loss 48.26022941527259
# Finish 143 epoch(es)
# step 144 - loss 42.99510955810547 - moving ave loss 47.73371742955588
# Finish 144 epoch(es)
# step 145 - loss 41.270442962646484 - moving ave loss 47.08738998286494
# Finish 145 epoch(es)
# step 146 - loss 41.259727478027344 - moving ave loss 46.504623732381184
# Finish 146 epoch(es)
# step 147 - loss 43.83305740356445 - moving ave loss 46.23746709949951
# Finish 147 epoch(es)
# step 148 - loss 42.287784576416016 - moving ave loss 45.842498847191166
# Finish 148 epoch(es)
# step 149 - loss 42.76299285888672 - moving ave loss 45.53454824836072
# Finish 149 epoch(es)
# step 150 - loss 41.85810852050781 - moving ave loss 45.166904275575426
# Finish 150 epoch(es)
# step 151 - loss 42.01648712158203 - moving ave loss 44.85186256017609
# Finish 151 epoch(es)
# step 152 - loss 41.09748077392578 - moving ave loss 44.47642438155106
# Finish 152 epoch(es)
# step 153 - loss 40.52201843261719 - moving ave loss 44.080983786657676
# Finish 153 epoch(es)
# step 154 - loss 39.3685302734375 - moving ave loss 43.60973843533566
# Finish 154 epoch(es)
# step 155 - loss 39.47782516479492 - moving ave loss 43.196547108281585
# Finish 155 epoch(es)
# step 156 - loss 37.605777740478516 - moving ave loss 42.63747017150128
# Finish 156 epoch(es)
# step 157 - loss 39.65544891357422 - moving ave loss 42.33926804570858
# Finish 157 epoch(es)
# step 158 - loss 38.338172912597656 - moving ave loss 41.939158532397485
# Finish 158 epoch(es)
# step 159 - loss 38.84584426879883 - moving ave loss 41.629827106037624
# Finish 159 epoch(es)
# step 160 - loss 40.26716613769531 - moving ave loss 41.49356100920339
# Finish 160 epoch(es)
# step 161 - loss 37.586753845214844 - moving ave loss 41.102880292804535
# Finish 161 epoch(es)
# step 162 - loss 36.87389373779297 - moving ave loss 40.67998163730338
# Finish 162 epoch(es)
# step 163 - loss 38.119140625 - moving ave loss 40.42389753607304
# Finish 163 epoch(es)
# step 164 - loss 38.711265563964844 - moving ave loss 40.25263433886222
# Finish 164 epoch(es)
# step 165 - loss 36.14521408081055 - moving ave loss 39.84189231305705
# Finish 165 epoch(es)
# step 166 - loss 36.114871978759766 - moving ave loss 39.46919027962732
# Finish 166 epoch(es)
# step 167 - loss 34.73646926879883 - moving ave loss 38.99591817854447
# Finish 167 epoch(es)
# step 168 - loss 34.25347900390625 - moving ave loss 38.521674261080655
# Finish 168 epoch(es)
# step 169 - loss 34.20555114746094 - moving ave loss 38.09006194971868
# Finish 169 epoch(es)
# step 170 - loss 34.42570495605469 - moving ave loss 37.72362625035228
# Finish 170 epoch(es)
# step 171 - loss 35.168922424316406 - moving ave loss 37.46815586774869
# Finish 171 epoch(es)
# step 172 - loss 36.31928253173828 - moving ave loss 37.35326853414765
# Finish 172 epoch(es)
# step 173 - loss 35.47804260253906 - moving ave loss 37.165745940986795
# Finish 173 epoch(es)
# step 174 - loss 33.86420440673828 - moving ave loss 36.835591787561945
# Finish 174 epoch(es)
# step 175 - loss 34.1370849609375 - moving ave loss 36.5657411048995
# Finish 175 epoch(es)
# step 176 - loss 34.47544479370117 - moving ave loss 36.35671147377967
# Finish 176 epoch(es)
# step 177 - loss 33.26411819458008 - moving ave loss 36.047452145859715
# Finish 177 epoch(es)
# step 178 - loss 34.443626403808594 - moving ave loss 35.88706957165461
# Finish 178 epoch(es)
# step 179 - loss 32.31871032714844 - moving ave loss 35.53023364720399
# Finish 179 epoch(es)
# step 180 - loss 33.48495864868164 - moving ave loss 35.32570614735176
# Finish 180 epoch(es)
# step 181 - loss 30.795957565307617 - moving ave loss 34.872731289147346
# Finish 181 epoch(es)
# step 182 - loss 29.66327667236328 - moving ave loss 34.351785827468944
# Finish 182 epoch(es)
# step 183 - loss 30.681196212768555 - moving ave loss 33.98472686599891
# Finish 183 epoch(es)
# step 184 - loss 30.839550018310547 - moving ave loss 33.67020918123007
# Finish 184 epoch(es)
# step 185 - loss 32.876041412353516 - moving ave loss 33.590792404342416
# Finish 185 epoch(es)
# step 186 - loss 29.876346588134766 - moving ave loss 33.21934782272165
# Finish 186 epoch(es)
# step 187 - loss 30.51772689819336 - moving ave loss 32.94918573026882
# Finish 187 epoch(es)
# step 188 - loss 29.4858341217041 - moving ave loss 32.602850569412354
# Finish 188 epoch(es)
# step 189 - loss 32.00856018066406 - moving ave loss 32.54342153053752
# Finish 189 epoch(es)
# step 190 - loss 34.57843017578125 - moving ave loss 32.746922395061894
# Finish 190 epoch(es)
# step 191 - loss 30.85226821899414 - moving ave loss 32.55745697745512
# Finish 191 epoch(es)
# step 192 - loss 31.062936782836914 - moving ave loss 32.4080049579933
# Finish 192 epoch(es)
# step 193 - loss 29.870376586914062 - moving ave loss 32.15424212088537
# Finish 193 epoch(es)
# step 194 - loss 30.098052978515625 - moving ave loss 31.9486232066484
# Finish 194 epoch(es)
# step 195 - loss 33.533233642578125 - moving ave loss 32.10708425024137
# Finish 195 epoch(es)
# step 196 - loss 28.441261291503906 - moving ave loss 31.740501954367623
# Finish 196 epoch(es)
# step 197 - loss 27.401168823242188 - moving ave loss 31.30656864125508
# Finish 197 epoch(es)
# step 198 - loss 27.322275161743164 - moving ave loss 30.908139293303886
# Finish 198 epoch(es)
# step 199 - loss 28.58314323425293 - moving ave loss 30.675639687398792
# Finish 199 epoch(es)
# step 200 - loss 30.84656524658203 - moving ave loss 30.692732243317117
# Finish 200 epoch(es)
# step 201 - loss 26.680156707763672 - moving ave loss 30.291474689761774
# Finish 201 epoch(es)
# step 202 - loss 26.746610641479492 - moving ave loss 29.93698828493355
# Finish 202 epoch(es)
# step 203 - loss 25.86309814453125 - moving ave loss 29.52959927089332
# Finish 203 epoch(es)
# step 204 - loss 33.208709716796875 - moving ave loss 29.89751031548368
# Finish 204 epoch(es)
# step 205 - loss 27.180301666259766 - moving ave loss 29.62578945056129
# Finish 205 epoch(es)
# step 206 - loss 27.483795166015625 - moving ave loss 29.411590022106722
# Finish 206 epoch(es)
# step 207 - loss 27.285259246826172 - moving ave loss 29.19895694457867
# Finish 207 epoch(es)
# step 208 - loss 26.704952239990234 - moving ave loss 28.949556474119824
# Finish 208 epoch(es)
# step 209 - loss 26.288721084594727 - moving ave loss 28.683472935167313
# Finish 209 epoch(es)
# step 210 - loss 27.722370147705078 - moving ave loss 28.58736265642109
# Finish 210 epoch(es)
# step 211 - loss 26.409984588623047 - moving ave loss 28.369624849641287
# Finish 211 epoch(es)
# step 212 - loss 25.622058868408203 - moving ave loss 28.09486825151798
# Finish 212 epoch(es)
# step 213 - loss 25.974246978759766 - moving ave loss 27.88280612424216
# Finish 213 epoch(es)
# step 214 - loss 26.143508911132812 - moving ave loss 27.708876402931224
# Finish 214 epoch(es)
# step 215 - loss 24.100427627563477 - moving ave loss 27.34803152539445
# Finish 215 epoch(es)
# step 216 - loss 26.19402313232422 - moving ave loss 27.232630686087425
# Finish 216 epoch(es)
# step 217 - loss 23.856197357177734 - moving ave loss 26.89498735319646
# Finish 217 epoch(es)
# step 218 - loss 26.82190704345703 - moving ave loss 26.887679322222517
# Finish 218 epoch(es)
# step 219 - loss 24.068012237548828 - moving ave loss 26.60571261375515
# Finish 219 epoch(es)
# step 220 - loss 25.657470703125 - moving ave loss 26.510888422692133
# Finish 220 epoch(es)
# step 221 - loss 24.941036224365234 - moving ave loss 26.353903202859442
# Finish 221 epoch(es)
# step 222 - loss 23.138660430908203 - moving ave loss 26.032378925664318
# Finish 222 epoch(es)
# step 223 - loss 23.253870010375977 - moving ave loss 25.754528034135486
# Finish 223 epoch(es)
# step 224 - loss 22.6273193359375 - moving ave loss 25.441807164315687
# Finish 224 epoch(es)
# step 225 - loss 24.648075103759766 - moving ave loss 25.362433958260095
# Finish 225 epoch(es)
# step 226 - loss 23.024328231811523 - moving ave loss 25.12862338561524
# Finish 226 epoch(es)
# step 227 - loss 24.683359146118164 - moving ave loss 25.084096961665534
# Finish 227 epoch(es)
# step 228 - loss 24.35199546813965 - moving ave loss 25.010886812312947
# Finish 228 epoch(es)
# step 229 - loss 22.8646240234375 - moving ave loss 24.796260533425404
# Finish 229 epoch(es)
# step 230 - loss 22.04958724975586 - moving ave loss 24.52159320505845
# Finish 230 epoch(es)
# step 231 - loss 22.455005645751953 - moving ave loss 24.3149344491278
# Finish 231 epoch(es)
# step 232 - loss 24.992002487182617 - moving ave loss 24.382641252933283
# Finish 232 epoch(es)
# step 233 - loss 21.98563003540039 - moving ave loss 24.142940131179994
# Finish 233 epoch(es)
# step 234 - loss 22.169836044311523 - moving ave loss 23.94562972249315
# Finish 234 epoch(es)
# step 235 - loss 23.809955596923828 - moving ave loss 23.932062309936217
# Finish 235 epoch(es)
# step 236 - loss 23.123416900634766 - moving ave loss 23.851197769006074
# Finish 236 epoch(es)
# step 237 - loss 24.37441062927246 - moving ave loss 23.903519055032714
# Finish 237 epoch(es)
# step 238 - loss 22.302818298339844 - moving ave loss 23.74344897936343
# Finish 238 epoch(es)
# step 239 - loss 20.5362548828125 - moving ave loss 23.422729569708334
# Finish 239 epoch(es)
# step 240 - loss 26.82928466796875 - moving ave loss 23.763385079534373
# Finish 240 epoch(es)
# step 241 - loss 22.308090209960938 - moving ave loss 23.61785559257703
# Finish 241 epoch(es)
# step 242 - loss 23.771987915039062 - moving ave loss 23.633268824823237
# Finish 242 epoch(es)
# step 243 - loss 22.33338165283203 - moving ave loss 23.503280107624118
# Finish 243 epoch(es)
# step 244 - loss 23.460254669189453 - moving ave loss 23.498977563780652
# Finish 244 epoch(es)
# step 245 - loss 21.495563507080078 - moving ave loss 23.298636158110593
# Finish 245 epoch(es)
# step 246 - loss 23.429824829101562 - moving ave loss 23.31175502520969
# Finish 246 epoch(es)
# step 247 - loss 23.21956443786621 - moving ave loss 23.302535966475343
# Finish 247 epoch(es)
# step 248 - loss 21.824729919433594 - moving ave loss 23.15475536177117
# Finish 248 epoch(es)
# step 249 - loss 22.361534118652344 - moving ave loss 23.075433237459286
# Finish 249 epoch(es)
# step 250 - loss 21.24126625061035 - moving ave loss 22.892016538774392
# Checkpoint at step 250
# Finish 250 epoch(es)
# step 251 - loss 22.48785400390625 - moving ave loss 22.851600285287578
# Finish 251 epoch(es)
# step 252 - loss 21.118988037109375 - moving ave loss 22.678339060469757
# Finish 252 epoch(es)
# step 253 - loss 20.697603225708008 - moving ave loss 22.480265476993583
# Finish 253 epoch(es)
# step 254 - loss 21.146265029907227 - moving ave loss 22.34686543228495
# Finish 254 epoch(es)
# step 255 - loss 20.961339950561523 - moving ave loss 22.20831288411261
# Finish 255 epoch(es)
# step 256 - loss 20.01416015625 - moving ave loss 21.988897611326347
# Finish 256 epoch(es)
# step 257 - loss 22.40034294128418 - moving ave loss 22.03004214432213
# Finish 257 epoch(es)
# step 258 - loss 23.74959945678711 - moving ave loss 22.20199787556863
# Finish 258 epoch(es)
# step 259 - loss 22.89794158935547 - moving ave loss 22.271592246947314
# Finish 259 epoch(es)
# step 260 - loss 19.676715850830078 - moving ave loss 22.01210460733559
# Finish 260 epoch(es)
# step 261 - loss 20.684158325195312 - moving ave loss 21.87930997912156
# Finish 261 epoch(es)
# step 262 - loss 21.38376235961914 - moving ave loss 21.82975521717132
# Finish 262 epoch(es)
# step 263 - loss 20.19266700744629 - moving ave loss 21.66604639619882
# Finish 263 epoch(es)
# step 264 - loss 19.77444839477539 - moving ave loss 21.476886596056477
# Finish 264 epoch(es)
# step 265 - loss 26.13396453857422 - moving ave loss 21.94259439030825
# Finish 265 epoch(es)
# step 266 - loss 20.14691925048828 - moving ave loss 21.763026876326258
# Finish 266 epoch(es)
# step 267 - loss 19.20467758178711 - moving ave loss 21.507191946872343
# Finish 267 epoch(es)
# step 268 - loss 19.288015365600586 - moving ave loss 21.285274288745168
# Finish 268 epoch(es)
# step 269 - loss 22.277185440063477 - moving ave loss 21.384465403876998
# Finish 269 epoch(es)
# step 270 - loss 19.940235137939453 - moving ave loss 21.240042377283242
# Finish 270 epoch(es)
# step 271 - loss 18.869426727294922 - moving ave loss 21.00298081228441
# Finish 271 epoch(es)
# step 272 - loss 19.5736083984375 - moving ave loss 20.86004357089972
# Finish 272 epoch(es)
# step 273 - loss 18.80524444580078 - moving ave loss 20.654563658389826
# Finish 273 epoch(es)
# step 274 - loss 18.574588775634766 - moving ave loss 20.44656617011432
# Finish 274 epoch(es)
# step 275 - loss 18.723037719726562 - moving ave loss 20.274213325075547
# Finish 275 epoch(es)
# step 276 - loss 17.207347869873047 - moving ave loss 19.967526779555296
# Finish 276 epoch(es)
# step 277 - loss 19.57767105102539 - moving ave loss 19.928541206702306
# Finish 277 epoch(es)
# step 278 - loss 17.04309844970703 - moving ave loss 19.639996931002777
# Finish 278 epoch(es)
# step 279 - loss 17.176103591918945 - moving ave loss 19.393607597094395
# Finish 279 epoch(es)
# step 280 - loss 19.691181182861328 - moving ave loss 19.42336495567109
# Finish 280 epoch(es)
# step 281 - loss 20.824138641357422 - moving ave loss 19.563442324239723
# Finish 281 epoch(es)
# step 282 - loss 18.588756561279297 - moving ave loss 19.46597374794368
# Finish 282 epoch(es)
# step 283 - loss 16.884014129638672 - moving ave loss 19.207777786113176
# Finish 283 epoch(es)
# step 284 - loss 18.38896942138672 - moving ave loss 19.12589694964053
# Finish 284 epoch(es)
# step 285 - loss 19.597126007080078 - moving ave loss 19.17301985538449
# Finish 285 epoch(es)
# step 286 - loss 19.893508911132812 - moving ave loss 19.245068760959324
# Finish 286 epoch(es)
# step 287 - loss 18.365398406982422 - moving ave loss 19.157101725561635
# Finish 287 epoch(es)
# step 288 - loss 18.251434326171875 - moving ave loss 19.06653498562266
# Finish 288 epoch(es)
# step 289 - loss 17.378520965576172 - moving ave loss 18.897733583618013
# Finish 289 epoch(es)
# step 290 - loss 20.81173324584961 - moving ave loss 19.089133549841172
# Finish 290 epoch(es)
# step 291 - loss 17.781003952026367 - moving ave loss 18.958320590059692
# Finish 291 epoch(es)
# step 292 - loss 18.68102264404297 - moving ave loss 18.93059079545802
# Finish 292 epoch(es)
# step 293 - loss 17.338722229003906 - moving ave loss 18.77140393881261
# Finish 293 epoch(es)
# step 294 - loss 17.558271408081055 - moving ave loss 18.650090685739457
# Finish 294 epoch(es)
# step 295 - loss 17.968841552734375 - moving ave loss 18.581965772438952
# Finish 295 epoch(es)
# step 296 - loss 17.989376068115234 - moving ave loss 18.52270680200658
# Finish 296 epoch(es)
# step 297 - loss 19.991764068603516 - moving ave loss 18.669612528666274
# Finish 297 epoch(es)
# step 298 - loss 17.143430709838867 - moving ave loss 18.516994346783534
# Finish 298 epoch(es)
# step 299 - loss 17.92713165283203 - moving ave loss 18.458008077388385
# Finish 299 epoch(es)
# step 300 - loss 16.84693145751953 - moving ave loss 18.296900415401502
# Finish 300 epoch(es)
# step 301 - loss 18.050251007080078 - moving ave loss 18.27223547456936
# Finish 301 epoch(es)
# step 302 - loss 19.769235610961914 - moving ave loss 18.421935488208618
# Finish 302 epoch(es)
# step 303 - loss 17.872190475463867 - moving ave loss 18.366960986934142
# Finish 303 epoch(es)
# step 304 - loss 18.445995330810547 - moving ave loss 18.374864421321785
# Finish 304 epoch(es)
# step 305 - loss 17.586624145507812 - moving ave loss 18.296040393740387
# Finish 305 epoch(es)
# step 306 - loss 15.429420471191406 - moving ave loss 18.00937840148549
# Finish 306 epoch(es)
# step 307 - loss 19.099199295043945 - moving ave loss 18.118360490841333
# Finish 307 epoch(es)
# step 308 - loss 18.14564323425293 - moving ave loss 18.121088765182495
# Finish 308 epoch(es)
# step 309 - loss 19.149051666259766 - moving ave loss 18.223885055290225
# Finish 309 epoch(es)
# step 310 - loss 18.43292999267578 - moving ave loss 18.24478954902878
# Finish 310 epoch(es)
# step 311 - loss 18.632061004638672 - moving ave loss 18.28351669458977
# Finish 311 epoch(es)
# step 312 - loss 16.52829360961914 - moving ave loss 18.10799438609271
# Finish 312 epoch(es)
# step 313 - loss 15.567688941955566 - moving ave loss 17.853963841678997
# Finish 313 epoch(es)
# step 314 - loss 18.72167205810547 - moving ave loss 17.940734663321646
# Finish 314 epoch(es)
# step 315 - loss 16.357818603515625 - moving ave loss 17.782443057341045
# Finish 315 epoch(es)
# step 316 - loss 17.949602127075195 - moving ave loss 17.799158964314458
# Finish 316 epoch(es)
# step 317 - loss 17.40655517578125 - moving ave loss 17.75989858546114
# Finish 317 epoch(es)
# step 318 - loss 17.102962493896484 - moving ave loss 17.694204976304675
# Finish 318 epoch(es)
# step 319 - loss 16.923553466796875 - moving ave loss 17.617139825353895
# Finish 319 epoch(es)
# step 320 - loss 16.681161880493164 - moving ave loss 17.523542030867823
# Finish 320 epoch(es)
# step 321 - loss 20.137636184692383 - moving ave loss 17.78495144625028
# Finish 321 epoch(es)
# step 322 - loss 16.194692611694336 - moving ave loss 17.625925562794688
# Finish 322 epoch(es)
# step 323 - loss 17.692684173583984 - moving ave loss 17.632601423873616
# Finish 323 epoch(es)
# step 324 - loss 15.880315780639648 - moving ave loss 17.45737285955022
# Finish 324 epoch(es)
# step 325 - loss 15.777713775634766 - moving ave loss 17.289406951158675
# Finish 325 epoch(es)
# step 326 - loss 17.256351470947266 - moving ave loss 17.286101403137536
# Finish 326 epoch(es)
# step 327 - loss 16.58721923828125 - moving ave loss 17.216213186651906
# Finish 327 epoch(es)
# step 328 - loss 16.907390594482422 - moving ave loss 17.185330927434958
# Finish 328 epoch(es)
# step 329 - loss 15.804037094116211 - moving ave loss 17.047201544103082
# Finish 329 epoch(es)
# step 330 - loss 17.840499877929688 - moving ave loss 17.12653137748574
# Finish 330 epoch(es)
# step 331 - loss 16.680681228637695 - moving ave loss 17.081946362600938
# Finish 331 epoch(es)
# step 332 - loss 15.620023727416992 - moving ave loss 16.935754099082544
# Finish 332 epoch(es)
# step 333 - loss 16.54475212097168 - moving ave loss 16.896653901271456
# Finish 333 epoch(es)
# step 334 - loss 16.986186981201172 - moving ave loss 16.905607209264428
# Finish 334 epoch(es)
# step 335 - loss 15.94853401184082 - moving ave loss 16.809899889522068
# Finish 335 epoch(es)
# step 336 - loss 14.725896835327148 - moving ave loss 16.601499584102577
# Finish 336 epoch(es)
# step 337 - loss 16.276512145996094 - moving ave loss 16.569000840291928
# Finish 337 epoch(es)
# step 338 - loss 15.669191360473633 - moving ave loss 16.4790198923101
# Finish 338 epoch(es)
# step 339 - loss 19.17613410949707 - moving ave loss 16.748731314028795
# Finish 339 epoch(es)
# step 340 - loss 16.09064292907715 - moving ave loss 16.68292247553363
# Finish 340 epoch(es)
# step 341 - loss 15.8248872756958 - moving ave loss 16.59711895554985
# Finish 341 epoch(es)
# step 342 - loss 16.72162628173828 - moving ave loss 16.609569688168694
# Finish 342 epoch(es)
# step 343 - loss 16.485355377197266 - moving ave loss 16.597148257071552
# Finish 343 epoch(es)
# step 344 - loss 16.54666519165039 - moving ave loss 16.592099950529438
# Finish 344 epoch(es)
# step 345 - loss 15.217303276062012 - moving ave loss 16.454620283082694
# Finish 345 epoch(es)
# step 346 - loss 15.736970901489258 - moving ave loss 16.38285534492335
# Finish 346 epoch(es)
# step 347 - loss 18.059486389160156 - moving ave loss 16.55051844934703
# Finish 347 epoch(es)
# step 348 - loss 15.213129997253418 - moving ave loss 16.41677960413767
# Finish 348 epoch(es)
# step 349 - loss 17.963037490844727 - moving ave loss 16.571405392808376
# Finish 349 epoch(es)
# step 350 - loss 15.354722023010254 - moving ave loss 16.449737055828564
# Finish 350 epoch(es)
# step 351 - loss 15.516563415527344 - moving ave loss 16.356419691798443
# Finish 351 epoch(es)
# step 352 - loss 16.941883087158203 - moving ave loss 16.41496603133442
# Finish 352 epoch(es)
# step 353 - loss 14.950714111328125 - moving ave loss 16.268540839333788
# Finish 353 epoch(es)
# step 354 - loss 13.740989685058594 - moving ave loss 16.01578572390627
# Finish 354 epoch(es)
# step 355 - loss 14.377717018127441 - moving ave loss 15.851978853328387
# Finish 355 epoch(es)
# step 356 - loss 13.492652893066406 - moving ave loss 15.616046257302187
# Finish 356 epoch(es)
# step 357 - loss 14.925691604614258 - moving ave loss 15.547010792033394
# Finish 357 epoch(es)
# step 358 - loss 15.785101890563965 - moving ave loss 15.570819901886452
# Finish 358 epoch(es)
# step 359 - loss 15.208866119384766 - moving ave loss 15.534624523636285
# Finish 359 epoch(es)
# step 360 - loss 13.716202735900879 - moving ave loss 15.352782344862744
# Finish 360 epoch(es)
# step 361 - loss 15.760892868041992 - moving ave loss 15.39359339718067
# Finish 361 epoch(es)
# step 362 - loss 18.115474700927734 - moving ave loss 15.665781527555378
# Finish 362 epoch(es)
# step 363 - loss 16.402175903320312 - moving ave loss 15.739420965131872
# Finish 363 epoch(es)
# step 364 - loss 16.893375396728516 - moving ave loss 15.854816408291537
# Finish 364 epoch(es)
# step 365 - loss 15.775727272033691 - moving ave loss 15.846907494665754
# Finish 365 epoch(es)
# step 366 - loss 17.34320831298828 - moving ave loss 15.996537576498007
# Finish 366 epoch(es)
# step 367 - loss 14.970643997192383 - moving ave loss 15.893948218567445
# Finish 367 epoch(es)
# step 368 - loss 16.049789428710938 - moving ave loss 15.909532339581794
# Finish 368 epoch(es)
# step 369 - loss 15.118589401245117 - moving ave loss 15.830438045748126
# Finish 369 epoch(es)
# step 370 - loss 14.682226181030273 - moving ave loss 15.715616859276341
# Finish 370 epoch(es)
# step 371 - loss 13.983858108520508 - moving ave loss 15.54244098420076
# Finish 371 epoch(es)
# step 372 - loss 14.32907485961914 - moving ave loss 15.421104371742597
# Finish 372 epoch(es)
# step 373 - loss 14.632983207702637 - moving ave loss 15.342292255338602
# Finish 373 epoch(es)
# step 374 - loss 16.854488372802734 - moving ave loss 15.493511867085015
# Finish 374 epoch(es)
# step 375 - loss 18.81269645690918 - moving ave loss 15.825430326067433
# Checkpoint at step 375
# Finish 375 epoch(es)
# step 376 - loss 16.039690017700195 - moving ave loss 15.84685629523071
# Finish 376 epoch(es)
# step 377 - loss 13.109233856201172 - moving ave loss 15.573094051327757
# Finish 377 epoch(es)
# step 378 - loss 14.748434066772461 - moving ave loss 15.490628052872228
# Finish 378 epoch(es)
# step 379 - loss 15.836166381835938 - moving ave loss 15.5251818857686
# Finish 379 epoch(es)
# step 380 - loss 14.490073204040527 - moving ave loss 15.421671017595793
# Finish 380 epoch(es)
# step 381 - loss 14.526265144348145 - moving ave loss 15.332130430271029
# Finish 381 epoch(es)
# step 382 - loss 14.905431747436523 - moving ave loss 15.28946056198758
# Finish 382 epoch(es)
# step 383 - loss 12.682088851928711 - moving ave loss 15.028723390981694
# Finish 383 epoch(es)
# step 384 - loss 15.700538635253906 - moving ave loss 15.095904915408916
# Finish 384 epoch(es)
# step 385 - loss 14.368053436279297 - moving ave loss 15.023119767495954
# Finish 385 epoch(es)
# step 386 - loss 15.780338287353516 - moving ave loss 15.09884161948171
# Finish 386 epoch(es)
# step 387 - loss 14.99940013885498 - moving ave loss 15.088897471419038
# Finish 387 epoch(es)
# step 388 - loss 13.606341361999512 - moving ave loss 14.940641860477086
# Finish 388 epoch(es)
# step 389 - loss 12.488899230957031 - moving ave loss 14.69546759752508
# Finish 389 epoch(es)
# step 390 - loss 14.827325820922852 - moving ave loss 14.70865341986486
# Finish 390 epoch(es)
# step 391 - loss 14.773965835571289 - moving ave loss 14.715184661435503
# Finish 391 epoch(es)
# step 392 - loss 15.830745697021484 - moving ave loss 14.826740764994101
# Finish 392 epoch(es)
# step 393 - loss 13.348125457763672 - moving ave loss 14.678879234271058
# Finish 393 epoch(es)
# step 394 - loss 14.706418991088867 - moving ave loss 14.68163320995284
# Finish 394 epoch(es)
# step 395 - loss 16.66409683227539 - moving ave loss 14.879879572185096
# Finish 395 epoch(es)
# step 396 - loss 13.351099014282227 - moving ave loss 14.727001516394811
# Finish 396 epoch(es)
# step 397 - loss 14.662343978881836 - moving ave loss 14.720535762643514
# Finish 397 epoch(es)
# step 398 - loss 14.387012481689453 - moving ave loss 14.687183434548109
# Finish 398 epoch(es)
# step 399 - loss 14.45538330078125 - moving ave loss 14.664003421171424
# Finish 399 epoch(es)
# step 400 - loss 12.873417854309082 - moving ave loss 14.48494486448519
# Finish 400 epoch(es)
# step 401 - loss 14.751724243164062 - moving ave loss 14.511622802353077
# Finish 401 epoch(es)
# step 402 - loss 13.586973190307617 - moving ave loss 14.419157841148532
# Finish 402 epoch(es)
# step 403 - loss 13.425846099853516 - moving ave loss 14.319826667019031
# Finish 403 epoch(es)
# step 404 - loss 16.85497283935547 - moving ave loss 14.573341284252676
# Finish 404 epoch(es)
# step 405 - loss 14.264447212219238 - moving ave loss 14.54245187704933
# Finish 405 epoch(es)
# step 406 - loss 15.607010841369629 - moving ave loss 14.648907773481362
# Finish 406 epoch(es)
# step 407 - loss 12.539133071899414 - moving ave loss 14.437930303323167
# Finish 407 epoch(es)
# step 408 - loss 14.110400199890137 - moving ave loss 14.405177292979864
# Finish 408 epoch(es)
# step 409 - loss 13.517621994018555 - moving ave loss 14.316421763083735
# Finish 409 epoch(es)
# step 410 - loss 14.447556495666504 - moving ave loss 14.329535236342013
# Finish 410 epoch(es)
# step 411 - loss 18.396244049072266 - moving ave loss 14.736206117615039
# Finish 411 epoch(es)
# step 412 - loss 14.033308029174805 - moving ave loss 14.665916308771015
# Finish 412 epoch(es)
# step 413 - loss 15.799114227294922 - moving ave loss 14.779236100623407
# Finish 413 epoch(es)
# step 414 - loss 13.677648544311523 - moving ave loss 14.66907734499222
# Finish 414 epoch(es)
# step 415 - loss 13.731782913208008 - moving ave loss 14.5753479018138
# Finish 415 epoch(es)
# step 416 - loss 13.36209774017334 - moving ave loss 14.454022885649755
# Finish 416 epoch(es)
# step 417 - loss 12.401850700378418 - moving ave loss 14.248805667122621
# Finish 417 epoch(es)
# step 418 - loss 12.126949310302734 - moving ave loss 14.036620031440634
# Finish 418 epoch(es)
# step 419 - loss 12.285487174987793 - moving ave loss 13.86150674579535
# Finish 419 epoch(es)
# step 420 - loss 13.509636878967285 - moving ave loss 13.826319759112543
# Finish 420 epoch(es)
# step 421 - loss 17.07032585144043 - moving ave loss 14.150720368345333
# Finish 421 epoch(es)
# step 422 - loss 13.668387413024902 - moving ave loss 14.102487072813291
# Finish 422 epoch(es)
# step 423 - loss 13.119843482971191 - moving ave loss 14.004222713829082
# Finish 423 epoch(es)
# step 424 - loss 14.817927360534668 - moving ave loss 14.085593178499641
# Finish 424 epoch(es)
# step 425 - loss 12.393020629882812 - moving ave loss 13.91633592363796
# Finish 425 epoch(es)
# step 426 - loss 15.54110336303711 - moving ave loss 14.078812667577875
# Finish 426 epoch(es)
# step 427 - loss 13.765641212463379 - moving ave loss 14.047495522066425
# Finish 427 epoch(es)
# step 428 - loss 13.512506484985352 - moving ave loss 13.993996618358318
# Finish 428 epoch(es)
# step 429 - loss 15.178781509399414 - moving ave loss 14.112475107462428
# Finish 429 epoch(es)
# step 430 - loss 13.390830993652344 - moving ave loss 14.04031069608142
# Finish 430 epoch(es)
# step 431 - loss 12.855527877807617 - moving ave loss 13.921832414254041
# Finish 431 epoch(es)
# step 432 - loss 15.882865905761719 - moving ave loss 14.117935763404809
# Finish 432 epoch(es)
# step 433 - loss 15.1309814453125 - moving ave loss 14.219240331595579
# Finish 433 epoch(es)
# step 434 - loss 15.808051109313965 - moving ave loss 14.378121409367418
# Finish 434 epoch(es)
# step 435 - loss 13.460563659667969 - moving ave loss 14.286365634397473
# Finish 435 epoch(es)
# step 436 - loss 13.287628173828125 - moving ave loss 14.186491888340539
# Finish 436 epoch(es)
# step 437 - loss 12.259570121765137 - moving ave loss 13.993799711682998
# Finish 437 epoch(es)
# step 438 - loss 13.285442352294922 - moving ave loss 13.92296397574419
# Finish 438 epoch(es)
# step 439 - loss 14.795095443725586 - moving ave loss 14.01017712254233
# Finish 439 epoch(es)
# step 440 - loss 11.840585708618164 - moving ave loss 13.793217981149915
# Finish 440 epoch(es)
# step 441 - loss 12.460596084594727 - moving ave loss 13.659955791494397
# Finish 441 epoch(es)
# step 442 - loss 12.55289077758789 - moving ave loss 13.549249290103747
# Finish 442 epoch(es)
# step 443 - loss 11.581525802612305 - moving ave loss 13.352476941354603
# Finish 443 epoch(es)
# step 444 - loss 11.586614608764648 - moving ave loss 13.175890708095608
# Finish 444 epoch(es)
# step 445 - loss 12.937540054321289 - moving ave loss 13.152055642718176
# Finish 445 epoch(es)
# step 446 - loss 14.058833122253418 - moving ave loss 13.2427333906717
# Finish 446 epoch(es)
# step 447 - loss 13.129175186157227 - moving ave loss 13.231377570220253
# Finish 447 epoch(es)
# step 448 - loss 18.02653694152832 - moving ave loss 13.710893507351061
# Finish 448 epoch(es)
# step 449 - loss 13.165952682495117 - moving ave loss 13.656399424865466
# Finish 449 epoch(es)
# step 450 - loss 15.64947509765625 - moving ave loss 13.855706992144546
# Finish 450 epoch(es)
# step 451 - loss 13.360028266906738 - moving ave loss 13.806139119620765
# Finish 451 epoch(es)
# step 452 - loss 13.32297134399414 - moving ave loss 13.757822342058104
# Finish 452 epoch(es)
# step 453 - loss 13.280679702758789 - moving ave loss 13.710108078128172
# Finish 453 epoch(es)
# step 454 - loss 11.871663093566895 - moving ave loss 13.526263579672044
# Finish 454 epoch(es)
# step 455 - loss 15.482989311218262 - moving ave loss 13.721936152826666
# Finish 455 epoch(es)
# step 456 - loss 12.53767204284668 - moving ave loss 13.603509741828667
# Finish 456 epoch(es)
# step 457 - loss 10.948564529418945 - moving ave loss 13.338015220587694
# Finish 457 epoch(es)
# step 458 - loss 11.022052764892578 - moving ave loss 13.106418975018183
# Finish 458 epoch(es)
# step 459 - loss 11.550537109375 - moving ave loss 12.950830788453866
# Finish 459 epoch(es)
# step 460 - loss 11.895362854003906 - moving ave loss 12.845283995008868
# Finish 460 epoch(es)
# step 461 - loss 13.682891845703125 - moving ave loss 12.929044780078293
# Finish 461 epoch(es)
# step 462 - loss 14.565272331237793 - moving ave loss 13.092667535194243
# Finish 462 epoch(es)
# step 463 - loss 13.445499420166016 - moving ave loss 13.127950723691422
# Finish 463 epoch(es)
# step 464 - loss 15.587311744689941 - moving ave loss 13.373886825791274
# Finish 464 epoch(es)
# step 465 - loss 12.86903190612793 - moving ave loss 13.323401333824942
# Finish 465 epoch(es)
# step 466 - loss 11.752294540405273 - moving ave loss 13.166290654482975
# Finish 466 epoch(es)
# step 467 - loss 11.526515007019043 - moving ave loss 13.002313089736582
# Finish 467 epoch(es)
# step 468 - loss 13.770805358886719 - moving ave loss 13.079162316651596
# Finish 468 epoch(es)
# step 469 - loss 11.681001663208008 - moving ave loss 12.939346251307239
# Finish 469 epoch(es)
# step 470 - loss 17.070343017578125 - moving ave loss 13.352445927934326
# Finish 470 epoch(es)
# step 471 - loss 14.82962703704834 - moving ave loss 13.500164038845728
# Finish 471 epoch(es)
# step 472 - loss 11.668281555175781 - moving ave loss 13.316975790478734
# Finish 472 epoch(es)
# step 473 - loss 13.039119720458984 - moving ave loss 13.28919018347676
# Finish 473 epoch(es)
# step 474 - loss 13.83555793762207 - moving ave loss 13.343826958891292
# Finish 474 epoch(es)
# step 475 - loss 13.010845184326172 - moving ave loss 13.31052878143478
# Finish 475 epoch(es)
# step 476 - loss 10.584043502807617 - moving ave loss 13.037880253572064
# Finish 476 epoch(es)
# step 477 - loss 12.886407852172852 - moving ave loss 13.022733013432143
# Finish 477 epoch(es)
# step 478 - loss 11.373823165893555 - moving ave loss 12.857842028678284
# Finish 478 epoch(es)
# step 479 - loss 12.224456787109375 - moving ave loss 12.794503504521394
# Finish 479 epoch(es)
# step 480 - loss 13.017114639282227 - moving ave loss 12.816764617997478
# Finish 480 epoch(es)
# step 481 - loss 9.431123733520508 - moving ave loss 12.478200529549781
# Finish 481 epoch(es)
# step 482 - loss 9.882588386535645 - moving ave loss 12.218639315248367
# Finish 482 epoch(es)
# step 483 - loss 11.535118103027344 - moving ave loss 12.150287194026266
# Finish 483 epoch(es)
# step 484 - loss 13.39861011505127 - moving ave loss 12.275119486128766
# Finish 484 epoch(es)
# step 485 - loss 13.060794830322266 - moving ave loss 12.353687020548115
# Finish 485 epoch(es)
# step 486 - loss 11.285477638244629 - moving ave loss 12.246866082317766
# Finish 486 epoch(es)
# step 487 - loss 13.786767959594727 - moving ave loss 12.400856270045463
# Finish 487 epoch(es)
# step 488 - loss 14.517972946166992 - moving ave loss 12.612567937657616
# Finish 488 epoch(es)
# step 489 - loss 11.738235473632812 - moving ave loss 12.525134691255134
# Finish 489 epoch(es)
# step 490 - loss 14.870853424072266 - moving ave loss 12.759706564536847
# Finish 490 epoch(es)
# step 491 - loss 12.517014503479004 - moving ave loss 12.735437358431062
# Finish 491 epoch(es)
# step 492 - loss 11.712587356567383 - moving ave loss 12.633152358244695
# Finish 492 epoch(es)
# step 493 - loss 10.347166061401367 - moving ave loss 12.404553728560362
# Finish 493 epoch(es)
# step 494 - loss 11.98758602142334 - moving ave loss 12.36285695784666
# Finish 494 epoch(es)
# step 495 - loss 10.790412902832031 - moving ave loss 12.205612552345197
# Finish 495 epoch(es)
# step 496 - loss 10.065133094787598 - moving ave loss 11.991564606589437
# Finish 496 epoch(es)
# step 497 - loss 13.355989456176758 - moving ave loss 12.128007091548168
# Finish 497 epoch(es)
# step 498 - loss 11.98913288116455 - moving ave loss 12.114119670509806
# Finish 498 epoch(es)
# step 499 - loss 12.464666366577148 - moving ave loss 12.149174340116542
# Finish 499 epoch(es)
# step 500 - loss 13.130288124084473 - moving ave loss 12.247285718513336
# Checkpoint at step 500
# Finish 500 epoch(es)
# step 501 - loss 9.656390190124512 - moving ave loss 11.988196165674454
# Finish 501 epoch(es)
# step 502 - loss 10.60358715057373 - moving ave loss 11.849735264164382
# Finish 502 epoch(es)
# step 503 - loss 10.818328857421875 - moving ave loss 11.74659462349013
# Finish 503 epoch(es)
# step 504 - loss 12.069047927856445 - moving ave loss 11.778839953926763
# Finish 504 epoch(es)
# step 505 - loss 10.795337677001953 - moving ave loss 11.680489726234281
# Finish 505 epoch(es)
# step 506 - loss 13.467958450317383 - moving ave loss 11.859236598642592
# Finish 506 epoch(es)
# step 507 - loss 15.554283142089844 - moving ave loss 12.22874125298732
# Finish 507 epoch(es)
# step 508 - loss 12.690349578857422 - moving ave loss 12.274902085574329
# Finish 508 epoch(es)
# step 509 - loss 10.858892440795898 - moving ave loss 12.133301121096487
# Finish 509 epoch(es)
# step 510 - loss 12.515741348266602 - moving ave loss 12.171545143813498
# Finish 510 epoch(es)
# step 511 - loss 11.031730651855469 - moving ave loss 12.057563694617697
# Finish 511 epoch(es)
# step 512 - loss 12.019359588623047 - moving ave loss 12.053743284018232
# Finish 512 epoch(es)
# step 513 - loss 9.9337797164917 - moving ave loss 11.84174692726558
# Finish 513 epoch(es)
# step 514 - loss 11.65084457397461 - moving ave loss 11.822656691936483
# Finish 514 epoch(es)
# step 515 - loss 10.953195571899414 - moving ave loss 11.735710579932778
# Finish 515 epoch(es)
# step 516 - loss 10.061413764953613 - moving ave loss 11.568280898434862
# Finish 516 epoch(es)
# step 517 - loss 10.559894561767578 - moving ave loss 11.467442264768133
# Finish 517 epoch(es)
# step 518 - loss 11.588128089904785 - moving ave loss 11.4795108472818
# Finish 518 epoch(es)
# step 519 - loss 12.654949188232422 - moving ave loss 11.597054681376862
# Finish 519 epoch(es)
# step 520 - loss 11.727334976196289 - moving ave loss 11.610082710858805
# ...
# Finish 826 epoch(es)
# step 827 - loss 5.830073356628418 - moving ave loss 6.23405134548231
# Finish 827 epoch(es)
# step 828 - loss 5.436575889587402 - moving ave loss 6.154303799892819
# Finish 828 epoch(es)
# step 829 - loss 5.639203071594238 - moving ave loss 6.102793727062961
# Finish 829 epoch(es)
# step 830 - loss 5.406741142272949 - moving ave loss 6.03318846858396
# Finish 830 epoch(es)
# step 831 - loss 7.095148086547852 - moving ave loss 6.13938443038035
# Finish 831 epoch(es)
# step 832 - loss 6.655849456787109 - moving ave loss 6.191030933021026
# Finish 832 epoch(es)
# step 833 - loss 4.918435096740723 - moving ave loss 6.0637713493929954
# Finish 833 epoch(es)
# step 834 - loss 4.592428684234619 - moving ave loss 5.916637082877158
# Finish 834 epoch(es)
# step 835 - loss 8.331917762756348 - moving ave loss 6.158165150865077
# Finish 835 epoch(es)
# step 836 - loss 4.732690334320068 - moving ave loss 6.0156176692105765
# Finish 836 epoch(es)
# step 837 - loss 5.39976692199707 - moving ave loss 5.954032594489226
# Finish 837 epoch(es)
# step 838 - loss 6.0275421142578125 - moving ave loss 5.9613835464660845
# Finish 838 epoch(es)
# step 839 - loss 6.067039489746094 - moving ave loss 5.971949140794086
# Finish 839 epoch(es)
# step 840 - loss 5.591517448425293 - moving ave loss 5.9339059715572064
# Finish 840 epoch(es)
# step 841 - loss 7.177985668182373 - moving ave loss 6.058313941219723
# Finish 841 epoch(es)
# step 842 - loss 5.102776527404785 - moving ave loss 5.96276019983823
# Finish 842 epoch(es)
# step 843 - loss 9.324369430541992 - moving ave loss 6.298921122908606
# Finish 843 epoch(es)
# step 844 - loss 4.546847343444824 - moving ave loss 6.123713744962228
# Finish 844 epoch(es)
# step 845 - loss 5.119778633117676 - moving ave loss 6.023320233777773
# Finish 845 epoch(es)
# step 846 - loss 7.601795196533203 - moving ave loss 6.181167730053316
# Finish 846 epoch(es)
# step 847 - loss 3.7122719287872314 - moving ave loss 5.934278149926707
# Finish 847 epoch(es)
# step 848 - loss 4.745146751403809 - moving ave loss 5.815365010074418
# Finish 848 epoch(es)
# step 849 - loss 4.458240985870361 - moving ave loss 5.679652607654012
# Finish 849 epoch(es)
# step 850 - loss 5.105833053588867 - moving ave loss 5.622270652247498
# Finish 850 epoch(es)
# step 851 - loss 7.423795700073242 - moving ave loss 5.802423157030073
# Finish 851 epoch(es)
# step 852 - loss 5.103985786437988 - moving ave loss 5.732579419970865
# Finish 852 epoch(es)
# step 853 - loss 7.088293075561523 - moving ave loss 5.868150785529931
# Finish 853 epoch(es)
# step 854 - loss 4.633119106292725 - moving ave loss 5.74464761760621
# Finish 854 epoch(es)
# step 855 - loss 5.591119766235352 - moving ave loss 5.729294832469125
# Finish 855 epoch(es)
# step 856 - loss 6.992194175720215 - moving ave loss 5.855584766794235
# Finish 856 epoch(es)
# step 857 - loss 5.146270751953125 - moving ave loss 5.784653365310123
# Finish 857 epoch(es)
# step 858 - loss 6.4132256507873535 - moving ave loss 5.847510593857846
# Finish 858 epoch(es)
# step 859 - loss 3.144413948059082 - moving ave loss 5.5772009292779705
# Finish 859 epoch(es)
# step 860 - loss 7.737548828125 - moving ave loss 5.7932357191626735
# Finish 860 epoch(es)
# step 861 - loss 6.479867935180664 - moving ave loss 5.8618989407644735
# Finish 861 epoch(es)
# step 862 - loss 4.074275970458984 - moving ave loss 5.683136643733924
# Finish 862 epoch(es)
# step 863 - loss 3.98936128616333 - moving ave loss 5.513759107976864
# Finish 863 epoch(es)
# step 864 - loss 6.705538749694824 - moving ave loss 5.6329370721486605
# Finish 864 epoch(es)
# step 865 - loss 7.012269973754883 - moving ave loss 5.7708703623092825
# Finish 865 epoch(es)
# step 866 - loss 6.774540901184082 - moving ave loss 5.871237416196763
# Finish 866 epoch(es)
# step 867 - loss 7.161227703094482 - moving ave loss 6.000236444886536
# Finish 867 epoch(es)
# step 868 - loss 6.331520080566406 - moving ave loss 6.033364808454523
# Finish 868 epoch(es)
# step 869 - loss 6.394532203674316 - moving ave loss 6.069481547976502
# Finish 869 epoch(es)
# step 870 - loss 5.718533039093018 - moving ave loss 6.034386697088154
# Finish 870 epoch(es)
# step 871 - loss 4.195284843444824 - moving ave loss 5.850476511723821
# Finish 871 epoch(es)
# step 872 - loss 6.956902980804443 - moving ave loss 5.961119158631884
# Finish 872 epoch(es)
# step 873 - loss 9.905630111694336 - moving ave loss 6.355570253938129
# Finish 873 epoch(es)
# step 874 - loss 5.756916046142578 - moving ave loss 6.295704833158575
# Finish 874 epoch(es)
# step 875 - loss 7.03387975692749 - moving ave loss 6.369522325535466
# Checkpoint at step 875
# Finish 875 epoch(es)
# step 876 - loss 7.209362506866455 - moving ave loss 6.453506343668566
# Finish 876 epoch(es)
# step 877 - loss 5.20341157913208 - moving ave loss 6.328496867214917
# Finish 877 epoch(es)
# step 878 - loss 5.804585933685303 - moving ave loss 6.276105773861956
# Finish 878 epoch(es)
# step 879 - loss 5.696551322937012 - moving ave loss 6.218150328769462
# Finish 879 epoch(es)
# step 880 - loss 5.941904544830322 - moving ave loss 6.1905257503755475
# Finish 880 epoch(es)
# step 881 - loss 6.530989646911621 - moving ave loss 6.224572140029156
# Finish 881 epoch(es)
# step 882 - loss 6.580011367797852 - moving ave loss 6.260116062806025
# Finish 882 epoch(es)
# step 883 - loss 4.999889373779297 - moving ave loss 6.134093393903353
# Finish 883 epoch(es)
# step 884 - loss 6.298338413238525 - moving ave loss 6.15051789583687
# Finish 884 epoch(es)
# step 885 - loss 7.103725910186768 - moving ave loss 6.245838697271861
# Finish 885 epoch(es)
# step 886 - loss 6.465943336486816 - moving ave loss 6.2678491611933564
# Finish 886 epoch(es)
# step 887 - loss 3.8352761268615723 - moving ave loss 6.024591857760178
# Finish 887 epoch(es)
# step 888 - loss 5.101269721984863 - moving ave loss 5.932259644182647
# Finish 888 epoch(es)
# step 889 - loss 4.709166526794434 - moving ave loss 5.809950332443826
# Finish 889 epoch(es)
# step 890 - loss 4.157479286193848 - moving ave loss 5.6447032278188285
# Finish 890 epoch(es)
# step 891 - loss 6.70005989074707 - moving ave loss 5.750238894111653
# Finish 891 epoch(es)
# step 892 - loss 6.524655818939209 - moving ave loss 5.827680586594409
# Finish 892 epoch(es)
# step 893 - loss 5.463059425354004 - moving ave loss 5.791218470470368
# Finish 893 epoch(es)
# step 894 - loss 6.165112495422363 - moving ave loss 5.828607872965568
# Finish 894 epoch(es)
# step 895 - loss 7.151846408843994 - moving ave loss 5.960931726553411
# Finish 895 epoch(es)
# step 896 - loss 6.414115905761719 - moving ave loss 6.006250144474241
# Finish 896 epoch(es)
# step 897 - loss 6.376708507537842 - moving ave loss 6.043295980780602
# Finish 897 epoch(es)
# step 898 - loss 4.572667598724365 - moving ave loss 5.896233142574979
# Finish 898 epoch(es)
# step 899 - loss 6.19716739654541 - moving ave loss 5.926326567972023
# Finish 899 epoch(es)
# step 900 - loss 7.0276970863342285 - moving ave loss 6.036463619808243
# Finish 900 epoch(es)
# step 901 - loss 4.921687126159668 - moving ave loss 5.924985970443386
# Finish 901 epoch(es)
# step 902 - loss 6.961467742919922 - moving ave loss 6.028634147691039
# Finish 902 epoch(es)
# step 903 - loss 4.791338920593262 - moving ave loss 5.904904624981262
# Finish 903 epoch(es)
# step 904 - loss 6.600644588470459 - moving ave loss 5.9744786213301815
# Finish 904 epoch(es)
# step 905 - loss 6.507536888122559 - moving ave loss 6.027784448009419
# Finish 905 epoch(es)
# step 906 - loss 7.436089038848877 - moving ave loss 6.168614907093366
# Finish 906 epoch(es)
# step 907 - loss 5.217740058898926 - moving ave loss 6.073527422273922
# Finish 907 epoch(es)
# step 908 - loss 4.665680885314941 - moving ave loss 5.932742768578024
# Finish 908 epoch(es)
# step 909 - loss 5.150204181671143 - moving ave loss 5.854488909887335
# Finish 909 epoch(es)
# step 910 - loss 5.557991027832031 - moving ave loss 5.824839121681805
# Finish 910 epoch(es)
# step 911 - loss 5.998197555541992 - moving ave loss 5.842174965067824
# Finish 911 epoch(es)
# step 912 - loss 5.702694892883301 - moving ave loss 5.828226957849372
# Finish 912 epoch(es)
# step 913 - loss 5.861661434173584 - moving ave loss 5.831570405481793
# Finish 913 epoch(es)
# step 914 - loss 5.908388614654541 - moving ave loss 5.8392522263990685
# Finish 914 epoch(es)
# step 915 - loss 5.717672348022461 - moving ave loss 5.827094238561409
# Finish 915 epoch(es)
# step 916 - loss 4.979217529296875 - moving ave loss 5.742306567634955
# Finish 916 epoch(es)
# step 917 - loss 7.829349517822266 - moving ave loss 5.951010862653686
# Finish 917 epoch(es)
# step 918 - loss 5.4863691329956055 - moving ave loss 5.904546689687878
# Finish 918 epoch(es)
# step 919 - loss 6.920839309692383 - moving ave loss 6.006175951688329
# Finish 919 epoch(es)
# step 920 - loss 6.000469207763672 - moving ave loss 6.005605277295863
# Finish 920 epoch(es)
# step 921 - loss 4.527530193328857 - moving ave loss 5.857797768899163
# Finish 921 epoch(es)
# step 922 - loss 5.829234600067139 - moving ave loss 5.85494145201596
# Finish 922 epoch(es)
# step 923 - loss 5.235226631164551 - moving ave loss 5.792969969930819
# Finish 923 epoch(es)
# step 924 - loss 4.202777862548828 - moving ave loss 5.6339507591926195
# Finish 924 epoch(es)
# step 925 - loss 4.580773830413818 - moving ave loss 5.52863306631474
# Finish 925 epoch(es)
# step 926 - loss 8.753774642944336 - moving ave loss 5.8511472239777
# Finish 926 epoch(es)
# step 927 - loss 4.908291339874268 - moving ave loss 5.756861635567357
# Finish 927 epoch(es)
# step 928 - loss 7.392481803894043 - moving ave loss 5.920423652400026
# Finish 928 epoch(es)
# step 929 - loss 7.848162651062012 - moving ave loss 6.113197552266224
# Finish 929 epoch(es)
# step 930 - loss 7.609074592590332 - moving ave loss 6.262785256298635
# Finish 930 epoch(es)
# step 931 - loss 4.843683242797852 - moving ave loss 6.120875054948557
# Finish 931 epoch(es)
# step 932 - loss 5.003962516784668 - moving ave loss 6.009183801132168
# Finish 932 epoch(es)
# step 933 - loss 5.351056098937988 - moving ave loss 5.9433710309127505
# Finish 933 epoch(es)
# step 934 - loss 4.872940540313721 - moving ave loss 5.836327981852848
# Finish 934 epoch(es)
# step 935 - loss 5.532950401306152 - moving ave loss 5.805990223798179
# Finish 935 epoch(es)
# step 936 - loss 5.3170623779296875 - moving ave loss 5.75709743921133
# Finish 936 epoch(es)
# step 937 - loss 6.459341526031494 - moving ave loss 5.827321847893347
# Finish 937 epoch(es)
# step 938 - loss 3.8160080909729004 - moving ave loss 5.626190472201302
# Finish 938 epoch(es)
# step 939 - loss 5.026335716247559 - moving ave loss 5.566204996605928
# Finish 939 epoch(es)
# step 940 - loss 5.119429588317871 - moving ave loss 5.521527455777123
# Finish 940 epoch(es)
# step 941 - loss 4.19403076171875 - moving ave loss 5.388777786371286
# Finish 941 epoch(es)
# step 942 - loss 9.429271697998047 - moving ave loss 5.792827177533962
# Finish 942 epoch(es)
# step 943 - loss 6.748568534851074 - moving ave loss 5.888401313265673
# Finish 943 epoch(es)
# step 944 - loss 6.447220802307129 - moving ave loss 5.944283262169819
# Finish 944 epoch(es)
# step 945 - loss 6.676165580749512 - moving ave loss 6.017471494027788
# Finish 945 epoch(es)
# step 946 - loss 6.0026936531066895 - moving ave loss 6.015993709935678
# Finish 946 epoch(es)
# step 947 - loss 4.765079021453857 - moving ave loss 5.890902241087496
# Finish 947 epoch(es)
# step 948 - loss 5.211209297180176 - moving ave loss 5.822932946696764
# Finish 948 epoch(es)
# step 949 - loss 5.818716049194336 - moving ave loss 5.822511256946521
# Finish 949 epoch(es)
# step 950 - loss 6.226958274841309 - moving ave loss 5.862955958736
# Finish 950 epoch(es)
# step 951 - loss 6.267937183380127 - moving ave loss 5.9034540812004135
# Finish 951 epoch(es)
# step 952 - loss 11.621164321899414 - moving ave loss 6.475225105270314
# Finish 952 epoch(es)
# step 953 - loss 5.983994960784912 - moving ave loss 6.426102090821773
# Finish 953 epoch(es)
# step 954 - loss 5.878942489624023 - moving ave loss 6.371386130701999
# Finish 954 epoch(es)
# step 955 - loss 4.766752243041992 - moving ave loss 6.210922741935998
# Finish 955 epoch(es)
# step 956 - loss 7.282583236694336 - moving ave loss 6.318088791411832
# Finish 956 epoch(es)
# step 957 - loss 6.067821025848389 - moving ave loss 6.293062014855488
# Finish 957 epoch(es)
# step 958 - loss 6.155157566070557 - moving ave loss 6.279271569976995
# Finish 958 epoch(es)
# step 959 - loss 7.389561653137207 - moving ave loss 6.390300578293017
# Finish 959 epoch(es)
# step 960 - loss 6.464014053344727 - moving ave loss 6.397671925798188
# Finish 960 epoch(es)
# step 961 - loss 5.9446587562561035 - moving ave loss 6.35237060884398
# Finish 961 epoch(es)
# step 962 - loss 5.751112461090088 - moving ave loss 6.292244794068591
# Finish 962 epoch(es)
# step 963 - loss 6.561899185180664 - moving ave loss 6.319210233179798
# Finish 963 epoch(es)
# step 964 - loss 5.370626926422119 - moving ave loss 6.22435190250403
# Finish 964 epoch(es)
# step 965 - loss 8.559564590454102 - moving ave loss 6.457873171299037
# Finish 965 epoch(es)
# step 966 - loss 4.2475738525390625 - moving ave loss 6.23684323942304
# Finish 966 epoch(es)
# step 967 - loss 6.41615104675293 - moving ave loss 6.254774020156029
# Finish 967 epoch(es)
# step 968 - loss 6.421321392059326 - moving ave loss 6.271428757346358
# Finish 968 epoch(es)
# step 969 - loss 5.190523147583008 - moving ave loss 6.163338196370023
# Finish 969 epoch(es)
# step 970 - loss 6.812344551086426 - moving ave loss 6.228238831841663
# Finish 970 epoch(es)
# step 971 - loss 5.628147602081299 - moving ave loss 6.168229708865627
# Finish 971 epoch(es)
# step 972 - loss 8.051202774047852 - moving ave loss 6.35652701538385
# Finish 972 epoch(es)
# step 973 - loss 6.407880783081055 - moving ave loss 6.36166239215357
# Finish 973 epoch(es)
# step 974 - loss 5.594482421875 - moving ave loss 6.284944395125713
# Finish 974 epoch(es)
# step 975 - loss 6.569235801696777 - moving ave loss 6.313373535782819
# Finish 975 epoch(es)
# step 976 - loss 5.762035846710205 - moving ave loss 6.258239766875558
# Finish 976 epoch(es)
# step 977 - loss 5.191239356994629 - moving ave loss 6.151539725887466
# Finish 977 epoch(es)
# step 978 - loss 6.347531795501709 - moving ave loss 6.171138932848891
# Finish 978 epoch(es)
# step 979 - loss 6.012124538421631 - moving ave loss 6.155237493406165
# Finish 979 epoch(es)
# step 980 - loss 8.224740982055664 - moving ave loss 6.362187842271116
# Finish 980 epoch(es)
# step 981 - loss 6.007480621337891 - moving ave loss 6.326717120177793
# Finish 981 epoch(es)
# step 982 - loss 5.348776817321777 - moving ave loss 6.228923089892192
# Finish 982 epoch(es)
# step 983 - loss 5.678023815155029 - moving ave loss 6.173833162418476
# Finish 983 epoch(es)
# step 984 - loss 7.554243087768555 - moving ave loss 6.311874154953484
# Finish 984 epoch(es)
# step 985 - loss 6.625693321228027 - moving ave loss 6.343256071580939
# Finish 985 epoch(es)
# step 986 - loss 6.381361961364746 - moving ave loss 6.347066660559319
# Finish 986 epoch(es)
# step 987 - loss 6.068254470825195 - moving ave loss 6.319185441585907
# Finish 987 epoch(es)
# step 988 - loss 4.5595808029174805 - moving ave loss 6.143224977719064
# Finish 988 epoch(es)
# step 989 - loss 5.845983028411865 - moving ave loss 6.1135007827883445
# Finish 989 epoch(es)
# step 990 - loss 5.812621116638184 - moving ave loss 6.083412816173329
# Finish 990 epoch(es)
# step 991 - loss 6.062375545501709 - moving ave loss 6.081309089106168
# Finish 991 epoch(es)
# step 992 - loss 5.6525702476501465 - moving ave loss 6.038435204960566
# Finish 992 epoch(es)
# step 993 - loss 6.06935453414917 - moving ave loss 6.041527137879426
# Finish 993 epoch(es)
# step 994 - loss 5.224444389343262 - moving ave loss 5.95981886302581
# Finish 994 epoch(es)
# step 995 - loss 4.83822774887085 - moving ave loss 5.847659751610315
# Finish 995 epoch(es)
# step 996 - loss 6.10610818862915 - moving ave loss 5.873504595312198
# Finish 996 epoch(es)
# step 997 - loss 7.56320858001709 - moving ave loss 6.042474993782688
# Finish 997 epoch(es)
# step 998 - loss 4.915233612060547 - moving ave loss 5.929750855610473
# Finish 998 epoch(es)
# step 999 - loss 6.094628810882568 - moving ave loss 5.9462386511376835
# Finish 999 epoch(es)
# step 1000 - loss 5.968358039855957 - moving ave loss 5.948450590009511
# Checkpoint at step 1000
# Finish 1000 epoch(es)
# CPU times: user 20h 17min, sys: 7h 20min 37s, total: 1d 3h 37min 37s
# Wall time: 5h 40min 48s
