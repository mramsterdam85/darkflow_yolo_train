# %%
import cv2
from darkflow.net.build import TFNet
import matplotlib.pyplot as plt
# %config InlineBackend.figure_format = 'svg'
import tensorflow as tf

# %%
options = {
    "model":"cfg/yolov2-voc-1c-arrow-head.cfg",
    "load":"bin/yolov2-voc.weights",
    "epoch":1000,
    "train":True,
    "annotation":"train/annotations_small_arrow",
    "dataset":"train/images_small_arrow"
}

# %%
tfnet = TFNet(options)
# Out:
# Parsing ./cfg/yolov2-voc.cfg
# Parsing cfg/yolov2-voc-1c-arrow-head.cfg
# Loading bin/yolov2-voc.weights ...
# Successfully identified 202704264 bytes
# Finished in 0.7317309379577637s
#
# Building net ...
# Source | Train? | Layer description                | Output size
# -------+--------+----------------------------------+---------------
#        |        | input                            | (?, 416, 416, 3)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 416, 416, 32)
#  Load  |  Yep!  | maxp 2x2p0_2                     | (?, 208, 208, 32)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 208, 208, 64)
#  Load  |  Yep!  | maxp 2x2p0_2                     | (?, 104, 104, 64)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 104, 104, 128)
#  Load  |  Yep!  | conv 1x1p0_1  +bnorm  leaky      | (?, 104, 104, 64)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 104, 104, 128)
#  Load  |  Yep!  | maxp 2x2p0_2                     | (?, 52, 52, 128)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 52, 52, 256)
#  Load  |  Yep!  | conv 1x1p0_1  +bnorm  leaky      | (?, 52, 52, 128)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 52, 52, 256)
#  Load  |  Yep!  | maxp 2x2p0_2                     | (?, 26, 26, 256)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 26, 26, 512)
#  Load  |  Yep!  | conv 1x1p0_1  +bnorm  leaky      | (?, 26, 26, 256)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 26, 26, 512)
#  Load  |  Yep!  | conv 1x1p0_1  +bnorm  leaky      | (?, 26, 26, 256)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 26, 26, 512)
#  Load  |  Yep!  | maxp 2x2p0_2                     | (?, 13, 13, 512)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 13, 13, 1024)
#  Load  |  Yep!  | conv 1x1p0_1  +bnorm  leaky      | (?, 13, 13, 512)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 13, 13, 1024)
#  Load  |  Yep!  | conv 1x1p0_1  +bnorm  leaky      | (?, 13, 13, 512)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 13, 13, 1024)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 13, 13, 1024)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 13, 13, 1024)
#  Load  |  Yep!  | concat [16]                      | (?, 26, 26, 512)
#  Load  |  Yep!  | conv 1x1p0_1  +bnorm  leaky      | (?, 26, 26, 64)
#  Load  |  Yep!  | local flatten 2x2                | (?, 13, 13, 256)
#  Load  |  Yep!  | concat [27, 24]                  | (?, 13, 13, 1280)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 13, 13, 1024)
#  Init  |  Yep!  | conv 1x1p0_1    linear           | (?, 13, 13, 30)
# -------+--------+----------------------------------+---------------
# Running entirely on CPU
# cfg/yolov2-voc-1c-arrow-head.cfg loss hyper-parameters:
# 	H       = 13
# 	W       = 13
# 	box     = 5
# 	classes = 1
# 	scales  = [1.0, 5.0, 1.0, 1.0]
# Building cfg/yolov2-voc-1c-arrow-head.cfg loss
# Building cfg/yolov2-voc-1c-arrow-head.cfg train op
# Finished in 13.634710788726807s

# %%
# %%time
tfnet.train()
# Out:
# cfg/yolov2-voc-1c-arrow-head.cfg parsing train/annotations_small_arrow
# Parsing for ['arrow']
# [====================>]100%  000003.xml
# Statistics:
# arrow: 607
# Dataset size: 31
# Dataset of 31 instance(s)
# Training statistics:
# 	Learning rate : 1e-05
# 	Batch size    : 16
# 	Epoch number  : 1000
# 	Backup every  : 2000
# step 1 - loss 116.63128662109375 - moving ave loss 116.63128662109375
# Finish 1 epoch(es)
# step 2 - loss 114.48062133789062 - moving ave loss 116.41622009277344
# Finish 2 epoch(es)
# step 3 - loss 117.8819808959961 - moving ave loss 116.5627961730957
# Finish 3 epoch(es)
# step 4 - loss 112.40898895263672 - moving ave loss 116.14741545104981
# Finish 4 epoch(es)
# step 5 - loss 112.6668701171875 - moving ave loss 115.79936091766359
# Finish 5 epoch(es)
# step 6 - loss 112.09465026855469 - moving ave loss 115.4288898527527
# Finish 6 epoch(es)
# step 7 - loss 111.21762084960938 - moving ave loss 115.00776295243837
# Finish 7 epoch(es)
# step 8 - loss 111.44113159179688 - moving ave loss 114.65109981637423
# Finish 8 epoch(es)
# step 9 - loss 111.25846862792969 - moving ave loss 114.31183669752977
# Finish 9 epoch(es)
# step 10 - loss 110.18612670898438 - moving ave loss 113.89926569867524
# Finish 10 epoch(es)
# step 11 - loss 108.82516479492188 - moving ave loss 113.39185560829989
# Finish 11 epoch(es)
# step 12 - loss 110.49334716796875 - moving ave loss 113.10200476426678
# Finish 12 epoch(es)
# step 13 - loss 110.30632019042969 - moving ave loss 112.82243630688308
# Finish 13 epoch(es)
# step 14 - loss 110.50631713867188 - moving ave loss 112.59082439006197
# Finish 14 epoch(es)
# step 15 - loss 109.38658142089844 - moving ave loss 112.27040009314562
# Finish 15 epoch(es)
# step 16 - loss 106.82260131835938 - moving ave loss 111.72562021566699
# Finish 16 epoch(es)
# step 17 - loss 106.61740112304688 - moving ave loss 111.21479830640499
# Finish 17 epoch(es)
# step 18 - loss 108.13224792480469 - moving ave loss 110.90654326824496
# Finish 18 epoch(es)
# step 19 - loss 105.14141082763672 - moving ave loss 110.33003002418414
# Finish 19 epoch(es)
# step 20 - loss 104.49772644042969 - moving ave loss 109.7467996658087
# Finish 20 epoch(es)
# step 21 - loss 104.0538330078125 - moving ave loss 109.17750300000908
# Finish 21 epoch(es)
# step 22 - loss 104.03457641601562 - moving ave loss 108.66321034160974
# Finish 22 epoch(es)
# step 23 - loss 103.56122589111328 - moving ave loss 108.15301189656009
# Finish 23 epoch(es)
# step 24 - loss 100.29261016845703 - moving ave loss 107.36697172374978
# Finish 24 epoch(es)
# step 25 - loss 101.98176574707031 - moving ave loss 106.82845112608184
# Finish 25 epoch(es)
# step 26 - loss 103.16345977783203 - moving ave loss 106.46195199125687
# Finish 26 epoch(es)
# step 27 - loss 103.45310974121094 - moving ave loss 106.16106776625227
# Finish 27 epoch(es)
# step 28 - loss 101.21875 - moving ave loss 105.66683598962705
# Finish 28 epoch(es)
# step 29 - loss 100.35293579101562 - moving ave loss 105.13544596976591
# Finish 29 epoch(es)
# step 30 - loss 101.10599517822266 - moving ave loss 104.73250089061159
# Finish 30 epoch(es)
# step 31 - loss 98.01972961425781 - moving ave loss 104.06122376297623
# Finish 31 epoch(es)
# step 32 - loss 97.79161071777344 - moving ave loss 103.43426245845595
# Finish 32 epoch(es)
# step 33 - loss 97.83920288085938 - moving ave loss 102.8747565006963
# Finish 33 epoch(es)
# step 34 - loss 98.73049926757812 - moving ave loss 102.46033077738448
# Finish 34 epoch(es)
# step 35 - loss 96.07032775878906 - moving ave loss 101.82133047552495
# Finish 35 epoch(es)
# step 36 - loss 98.99427795410156 - moving ave loss 101.53862522338261
# Finish 36 epoch(es)
# step 37 - loss 94.92495727539062 - moving ave loss 100.87725842858342
# Finish 37 epoch(es)
# step 38 - loss 96.23749542236328 - moving ave loss 100.41328212796141
# Finish 38 epoch(es)
# step 39 - loss 96.57383728027344 - moving ave loss 100.0293376431926
# Finish 39 epoch(es)
# step 40 - loss 95.48629760742188 - moving ave loss 99.57503363961554
# Finish 40 epoch(es)
# step 41 - loss 94.7470474243164 - moving ave loss 99.09223501808563
# Finish 41 epoch(es)
# step 42 - loss 97.03021240234375 - moving ave loss 98.88603275651145
# Finish 42 epoch(es)
# step 43 - loss 93.12161254882812 - moving ave loss 98.30959073574311
# Finish 43 epoch(es)
# step 44 - loss 92.0457763671875 - moving ave loss 97.68320929888756
# Finish 44 epoch(es)
# step 45 - loss 92.81275939941406 - moving ave loss 97.19616430894021
# Finish 45 epoch(es)
# step 46 - loss 92.80154418945312 - moving ave loss 96.7567022969915
# Finish 46 epoch(es)
# step 47 - loss 92.05047607421875 - moving ave loss 96.28607967471423
# Finish 47 epoch(es)
# step 48 - loss 93.86500549316406 - moving ave loss 96.04397225655921
# Finish 48 epoch(es)
# step 49 - loss 90.93096923828125 - moving ave loss 95.53267195473143
# Finish 49 epoch(es)
# step 50 - loss 91.59915161132812 - moving ave loss 95.1393199203911
# Finish 50 epoch(es)
# step 51 - loss 89.5704116821289 - moving ave loss 94.5824290965649
# Finish 51 epoch(es)
# step 52 - loss 87.61578369140625 - moving ave loss 93.88576455604903
# Finish 52 epoch(es)
# step 53 - loss 88.7385025024414 - moving ave loss 93.37103835068827
# Finish 53 epoch(es)
# step 54 - loss 87.72239685058594 - moving ave loss 92.80617420067803
# Finish 54 epoch(es)
# step 55 - loss 91.2516860961914 - moving ave loss 92.65072539022937
# Finish 55 epoch(es)
# step 56 - loss 87.65603637695312 - moving ave loss 92.15125648890174
# Finish 56 epoch(es)
# step 57 - loss 88.39408874511719 - moving ave loss 91.77553971452329
# Finish 57 epoch(es)
# step 58 - loss 88.4576416015625 - moving ave loss 91.44374990322721
# Finish 58 epoch(es)
# step 59 - loss 86.41200256347656 - moving ave loss 90.94057516925216
# Finish 59 epoch(es)
# step 60 - loss 84.969970703125 - moving ave loss 90.34351472263944
# Finish 60 epoch(es)
# step 61 - loss 82.89602661132812 - moving ave loss 89.59876591150832
# Finish 61 epoch(es)
# step 62 - loss 82.0722885131836 - moving ave loss 88.84611817167585
# Finish 62 epoch(es)
# step 63 - loss 83.107177734375 - moving ave loss 88.27222412794578
# Finish 63 epoch(es)
# step 64 - loss 84.60183715820312 - moving ave loss 87.90518543097151
# Finish 64 epoch(es)
# step 65 - loss 84.07648468017578 - moving ave loss 87.52231535589195
# Finish 65 epoch(es)
# step 66 - loss 85.17942810058594 - moving ave loss 87.28802663036136
# Finish 66 epoch(es)
# step 67 - loss 84.78755187988281 - moving ave loss 87.03797915531351
# Finish 67 epoch(es)
# step 68 - loss 83.18464660644531 - moving ave loss 86.65264590042669
# Finish 68 epoch(es)
# step 69 - loss 80.7632827758789 - moving ave loss 86.06370958797191
# Finish 69 epoch(es)
# step 70 - loss 79.67463684082031 - moving ave loss 85.42480231325676
# Finish 70 epoch(es)
# step 71 - loss 80.956787109375 - moving ave loss 84.9780007928686
# Finish 71 epoch(es)
# step 72 - loss 81.60902404785156 - moving ave loss 84.6411031183669
# Finish 72 epoch(es)
# step 73 - loss 81.02389526367188 - moving ave loss 84.2793823328974
# Finish 73 epoch(es)
# step 74 - loss 79.71284484863281 - moving ave loss 83.82272858447094
# Finish 74 epoch(es)
# step 75 - loss 80.30244445800781 - moving ave loss 83.47070017182462
# Finish 75 epoch(es)
# step 76 - loss 81.77252197265625 - moving ave loss 83.30088235190779
# Finish 76 epoch(es)
# step 77 - loss 78.73348999023438 - moving ave loss 82.84414311574045
# Finish 77 epoch(es)
# step 78 - loss 75.3167495727539 - moving ave loss 82.0914037614418
# Finish 78 epoch(es)
# step 79 - loss 75.17935180664062 - moving ave loss 81.40019856596169
# Finish 79 epoch(es)
# step 80 - loss 74.75300598144531 - moving ave loss 80.73547930751005
# Finish 80 epoch(es)
# step 81 - loss 78.12681579589844 - moving ave loss 80.47461295634889
# Finish 81 epoch(es)
# step 82 - loss 76.49223327636719 - moving ave loss 80.07637498835072
# Finish 82 epoch(es)
# step 83 - loss 74.6136703491211 - moving ave loss 79.53010452442777
# Finish 83 epoch(es)
# step 84 - loss 75.1864242553711 - moving ave loss 79.09573649752211
# Finish 84 epoch(es)
# step 85 - loss 71.25584411621094 - moving ave loss 78.311747259391
# Finish 85 epoch(es)
# step 86 - loss 71.47994995117188 - moving ave loss 77.62856752856909
# Finish 86 epoch(es)
# step 87 - loss 72.10855865478516 - moving ave loss 77.07656664119071
# Finish 87 epoch(es)
# step 88 - loss 72.28190612792969 - moving ave loss 76.59710058986461
# Finish 88 epoch(es)
# step 89 - loss 75.9317626953125 - moving ave loss 76.5305668004094
# Finish 89 epoch(es)
# step 90 - loss 68.998291015625 - moving ave loss 75.77733922193097
# Finish 90 epoch(es)
# step 91 - loss 69.38103485107422 - moving ave loss 75.1377087848453
# Finish 91 epoch(es)
# step 92 - loss 72.31195068359375 - moving ave loss 74.85513297472015
# Finish 92 epoch(es)
# step 93 - loss 71.89897155761719 - moving ave loss 74.55951683300985
# Finish 93 epoch(es)
# step 94 - loss 65.55998229980469 - moving ave loss 73.65956337968935
# Finish 94 epoch(es)
# step 95 - loss 69.95230102539062 - moving ave loss 73.28883714425947
# Finish 95 epoch(es)
# step 96 - loss 69.43507385253906 - moving ave loss 72.90346081508744
# Finish 96 epoch(es)
# step 97 - loss 65.1432113647461 - moving ave loss 72.1274358700533
# Finish 97 epoch(es)
# step 98 - loss 66.52265930175781 - moving ave loss 71.56695821322376
# Finish 98 epoch(es)
# step 99 - loss 67.88627624511719 - moving ave loss 71.1988900164131
# Finish 99 epoch(es)
# step 100 - loss 65.91605377197266 - moving ave loss 70.67060639196906
# Finish 100 epoch(es)
# step 101 - loss 63.399986267089844 - moving ave loss 69.94354437948114
# Finish 101 epoch(es)
# step 102 - loss 63.53931427001953 - moving ave loss 69.30312136853499
# Finish 102 epoch(es)
# step 103 - loss 63.78794860839844 - moving ave loss 68.75160409252133
# Finish 103 epoch(es)
# step 104 - loss 62.088600158691406 - moving ave loss 68.08530369913834
# Finish 104 epoch(es)
# step 105 - loss 61.245208740234375 - moving ave loss 67.40129420324794
# Finish 105 epoch(es)
# step 106 - loss 64.26569366455078 - moving ave loss 67.08773414937824
# Finish 106 epoch(es)
# step 107 - loss 61.99610900878906 - moving ave loss 66.57857163531932
# Finish 107 epoch(es)
# step 108 - loss 61.00062942504883 - moving ave loss 66.02077741429227
# Finish 108 epoch(es)
# step 109 - loss 61.32709884643555 - moving ave loss 65.5514095575066
# Finish 109 epoch(es)
# step 110 - loss 61.39612579345703 - moving ave loss 65.13588118110165
# Finish 110 epoch(es)
# step 111 - loss 61.6284294128418 - moving ave loss 64.78513600427567
# Finish 111 epoch(es)
# step 112 - loss 62.680015563964844 - moving ave loss 64.5746239602446
# Finish 112 epoch(es)
# step 113 - loss 59.86204528808594 - moving ave loss 64.10336609302873
# Finish 113 epoch(es)
# step 114 - loss 58.21007537841797 - moving ave loss 63.514037021567646
# Finish 114 epoch(es)
# step 115 - loss 58.00695037841797 - moving ave loss 62.96332835725268
# Finish 115 epoch(es)
# step 116 - loss 61.570865631103516 - moving ave loss 62.824082084637766
# Finish 116 epoch(es)
# step 117 - loss 56.55461120605469 - moving ave loss 62.197134996779454
# Finish 117 epoch(es)
# step 118 - loss 59.02699279785156 - moving ave loss 61.88012077688667
# Finish 118 epoch(es)
# step 119 - loss 55.49689483642578 - moving ave loss 61.24179818284058
# Finish 119 epoch(es)
# step 120 - loss 56.580501556396484 - moving ave loss 60.77566852019618
# Finish 120 epoch(es)
# step 121 - loss 58.840431213378906 - moving ave loss 60.58214478951445
# Finish 121 epoch(es)
# step 122 - loss 54.44603729248047 - moving ave loss 59.96853403981106
# Finish 122 epoch(es)
# step 123 - loss 55.00993728637695 - moving ave loss 59.47267436446765
# Finish 123 epoch(es)
# step 124 - loss 53.08766174316406 - moving ave loss 58.83417310233729
# Finish 124 epoch(es)
# step 125 - loss 53.90281677246094 - moving ave loss 58.34103746934966
# Checkpoint at step 125
# Finish 125 epoch(es)
# step 126 - loss 50.39549255371094 - moving ave loss 57.546482977785786
# Finish 126 epoch(es)
# step 127 - loss 53.28717041015625 - moving ave loss 57.120551721022835
# Finish 127 epoch(es)
# step 128 - loss 51.53329849243164 - moving ave loss 56.56182639816372
# Finish 128 epoch(es)
# step 129 - loss 52.55579376220703 - moving ave loss 56.16122313456805
# Finish 129 epoch(es)
# step 130 - loss 51.9427375793457 - moving ave loss 55.739374579045815
# Finish 130 epoch(es)
# step 131 - loss 50.78655242919922 - moving ave loss 55.24409236406116
# Finish 131 epoch(es)
# step 132 - loss 51.37198257446289 - moving ave loss 54.85688138510133
# Finish 132 epoch(es)
# step 133 - loss 49.919822692871094 - moving ave loss 54.36317551587831
# Finish 133 epoch(es)
# step 134 - loss 48.575889587402344 - moving ave loss 53.78444692303072
# Finish 134 epoch(es)
# step 135 - loss 51.28361129760742 - moving ave loss 53.53436336048839
# Finish 135 epoch(es)
# step 136 - loss 49.62382507324219 - moving ave loss 53.14330953176378
# Finish 136 epoch(es)
# step 137 - loss 46.82600402832031 - moving ave loss 52.51157898141943
# Finish 137 epoch(es)
# step 138 - loss 45.33837127685547 - moving ave loss 51.79425821096304
# Finish 138 epoch(es)
# step 139 - loss 46.289825439453125 - moving ave loss 51.24381493381205
# Finish 139 epoch(es)
# step 140 - loss 45.72478485107422 - moving ave loss 50.69191192553827
# Finish 140 epoch(es)
# step 141 - loss 48.36091613769531 - moving ave loss 50.45881234675398
# Finish 141 epoch(es)
# step 142 - loss 48.20440673828125 - moving ave loss 50.233371785906705
# Finish 142 epoch(es)
# step 143 - loss 44.434547424316406 - moving ave loss 49.65348934974767
# Finish 143 epoch(es)
# step 144 - loss 44.173805236816406 - moving ave loss 49.10552093845455
# Finish 144 epoch(es)
# step 145 - loss 43.64820861816406 - moving ave loss 48.559789706425505
# Finish 145 epoch(es)
# step 146 - loss 42.823402404785156 - moving ave loss 47.98615097626148
# Finish 146 epoch(es)
# step 147 - loss 42.733238220214844 - moving ave loss 47.46085970065681
# Finish 147 epoch(es)
# step 148 - loss 42.22944641113281 - moving ave loss 46.93771837170441
# Finish 148 epoch(es)
# step 149 - loss 43.84192657470703 - moving ave loss 46.62813919200468
# Finish 149 epoch(es)
# step 150 - loss 40.63823699951172 - moving ave loss 46.02914897275539
# Finish 150 epoch(es)
# step 151 - loss 44.90013885498047 - moving ave loss 45.91624796097789
# Finish 151 epoch(es)
# step 152 - loss 41.124908447265625 - moving ave loss 45.43711400960667
# Finish 152 epoch(es)
# step 153 - loss 40.23784637451172 - moving ave loss 44.91718724609717
# Finish 153 epoch(es)
# step 154 - loss 39.49456024169922 - moving ave loss 44.37492454565737
# Finish 154 epoch(es)
# step 155 - loss 41.23114013671875 - moving ave loss 44.06054610476351
# Finish 155 epoch(es)
# step 156 - loss 37.966617584228516 - moving ave loss 43.45115325271001
# Finish 156 epoch(es)
# step 157 - loss 38.05681610107422 - moving ave loss 42.911719537546425
# Finish 157 epoch(es)
# step 158 - loss 39.83740234375 - moving ave loss 42.60428781816678
# Finish 158 epoch(es)
# step 159 - loss 40.48781204223633 - moving ave loss 42.39264024057373
# Finish 159 epoch(es)
# step 160 - loss 37.846649169921875 - moving ave loss 41.93804113350855
# Finish 160 epoch(es)
# step 161 - loss 37.22184371948242 - moving ave loss 41.46642139210594
# Finish 161 epoch(es)
# step 162 - loss 37.97028350830078 - moving ave loss 41.11680760372543
# Finish 162 epoch(es)
# step 163 - loss 35.724422454833984 - moving ave loss 40.577569088836285
# Finish 163 epoch(es)
# step 164 - loss 35.62842559814453 - moving ave loss 40.082654739767115
# Finish 164 epoch(es)
# step 165 - loss 34.44334411621094 - moving ave loss 39.518723677411494
# Finish 165 epoch(es)
# step 166 - loss 35.535526275634766 - moving ave loss 39.120403937233824
# Finish 166 epoch(es)
# step 167 - loss 35.082603454589844 - moving ave loss 38.71662388896943
# Finish 167 epoch(es)
# step 168 - loss 34.78672790527344 - moving ave loss 38.32363429059983
# Finish 168 epoch(es)
# step 169 - loss 34.71739196777344 - moving ave loss 37.96301005831719
# Finish 169 epoch(es)
# step 170 - loss 34.155311584472656 - moving ave loss 37.58224021093274
# Finish 170 epoch(es)
# step 171 - loss 35.9479866027832 - moving ave loss 37.41881485011779
# Finish 171 epoch(es)
# step 172 - loss 33.25943374633789 - moving ave loss 37.0028767397398
# Finish 172 epoch(es)
# step 173 - loss 34.351016998291016 - moving ave loss 36.73769076559492
# Finish 173 epoch(es)
# step 174 - loss 33.8782958984375 - moving ave loss 36.45175127887918
# Finish 174 epoch(es)
# step 175 - loss 34.95956039428711 - moving ave loss 36.302532190419974
# Finish 175 epoch(es)
# step 176 - loss 32.716129302978516 - moving ave loss 35.943891901675826
# Finish 176 epoch(es)
# step 177 - loss 31.75618553161621 - moving ave loss 35.52512126466986
# Finish 177 epoch(es)
# step 178 - loss 31.522663116455078 - moving ave loss 35.12487544984838
# Finish 178 epoch(es)
# step 179 - loss 31.97759246826172 - moving ave loss 34.81014715168972
# Finish 179 epoch(es)
# step 180 - loss 33.03404235839844 - moving ave loss 34.632536672360594
# Finish 180 epoch(es)
# step 181 - loss 31.719676971435547 - moving ave loss 34.34125070226809
# Finish 181 epoch(es)
# step 182 - loss 31.38811492919922 - moving ave loss 34.045937124961206
# Finish 182 epoch(es)
# step 183 - loss 29.115009307861328 - moving ave loss 33.55284434325122
# Finish 183 epoch(es)
# step 184 - loss 29.83686065673828 - moving ave loss 33.18124597459993
# Finish 184 epoch(es)
# step 185 - loss 29.696834564208984 - moving ave loss 32.832804833560836
# Finish 185 epoch(es)
# step 186 - loss 30.108577728271484 - moving ave loss 32.5603821230319
# Finish 186 epoch(es)
# step 187 - loss 30.577688217163086 - moving ave loss 32.36211273244502
# Finish 187 epoch(es)
# step 188 - loss 29.448787689208984 - moving ave loss 32.07078022812142
# Finish 188 epoch(es)
# step 189 - loss 28.94245147705078 - moving ave loss 31.75794735301436
# Finish 189 epoch(es)
# step 190 - loss 30.450035095214844 - moving ave loss 31.62715612723441
# Finish 190 epoch(es)
# step 191 - loss 28.57520294189453 - moving ave loss 31.32196080870042
# Finish 191 epoch(es)
# step 192 - loss 28.423259735107422 - moving ave loss 31.032090701341122
# Finish 192 epoch(es)
# step 193 - loss 29.642179489135742 - moving ave loss 30.893099580120584
# Finish 193 epoch(es)
# step 194 - loss 28.70522117614746 - moving ave loss 30.674311739723272
# Finish 194 epoch(es)
# step 195 - loss 29.126834869384766 - moving ave loss 30.51956405268942
# Finish 195 epoch(es)
# step 196 - loss 28.363842010498047 - moving ave loss 30.303991848470282
# Finish 196 epoch(es)
# step 197 - loss 27.85568618774414 - moving ave loss 30.059161282397667
# Finish 197 epoch(es)
# step 198 - loss 28.480588912963867 - moving ave loss 29.90130404545429
# Finish 198 epoch(es)
# step 199 - loss 29.69253921508789 - moving ave loss 29.88042756241765
# Finish 199 epoch(es)
# step 200 - loss 29.370466232299805 - moving ave loss 29.82943142940587
# Finish 200 epoch(es)
# step 201 - loss 28.64745330810547 - moving ave loss 29.711233617275827
# Finish 201 epoch(es)
# step 202 - loss 28.617961883544922 - moving ave loss 29.601906443902738
# Finish 202 epoch(es)
# step 203 - loss 27.767425537109375 - moving ave loss 29.418458353223404
# Finish 203 epoch(es)
# step 204 - loss 27.04424285888672 - moving ave loss 29.181036803789738
# Finish 204 epoch(es)
# step 205 - loss 27.54388999938965 - moving ave loss 29.01732212334973
# Finish 205 epoch(es)
# step 206 - loss 28.58041763305664 - moving ave loss 28.97363167432042
# Finish 206 epoch(es)
# step 207 - loss 26.096460342407227 - moving ave loss 28.6859145411291
# Finish 207 epoch(es)
# step 208 - loss 27.376079559326172 - moving ave loss 28.55493104294881
# Finish 208 epoch(es)
# step 209 - loss 26.12234878540039 - moving ave loss 28.31167281719397
# Finish 209 epoch(es)
# step 210 - loss 25.91214370727539 - moving ave loss 28.071719906202112
# Finish 210 epoch(es)
# step 211 - loss 27.186634063720703 - moving ave loss 27.98321132195397
# Finish 211 epoch(es)
# step 212 - loss 25.436264038085938 - moving ave loss 27.728516593567168
# Finish 212 epoch(es)
# step 213 - loss 24.9095458984375 - moving ave loss 27.4466195240542
# Finish 213 epoch(es)
# step 214 - loss 24.7435302734375 - moving ave loss 27.17631059899253
# Finish 214 epoch(es)
# step 215 - loss 26.211002349853516 - moving ave loss 27.07977977407863
# Finish 215 epoch(es)
# step 216 - loss 24.513269424438477 - moving ave loss 26.82312873911462
# Finish 216 epoch(es)
# step 217 - loss 25.604068756103516 - moving ave loss 26.70122274081351
# Finish 217 epoch(es)
# step 218 - loss 26.10883331298828 - moving ave loss 26.64198379803099
# Finish 218 epoch(es)
# step 219 - loss 29.48011016845703 - moving ave loss 26.925796435073593
# Finish 219 epoch(es)
# step 220 - loss 25.119464874267578 - moving ave loss 26.745163278992994
# Finish 220 epoch(es)
# step 221 - loss 24.36495590209961 - moving ave loss 26.507142541303658
# Finish 221 epoch(es)
# step 222 - loss 25.223718643188477 - moving ave loss 26.378800151492143
# Finish 222 epoch(es)
# step 223 - loss 26.235105514526367 - moving ave loss 26.364430687795565
# Finish 223 epoch(es)
# step 224 - loss 24.336406707763672 - moving ave loss 26.161628289792375
# Finish 224 epoch(es)
# step 225 - loss 24.331295013427734 - moving ave loss 25.97859496215591
# Finish 225 epoch(es)
# step 226 - loss 24.335464477539062 - moving ave loss 25.814281913694224
# Finish 226 epoch(es)
# step 227 - loss 24.504005432128906 - moving ave loss 25.68325426553769
# Finish 227 epoch(es)
# step 228 - loss 23.001609802246094 - moving ave loss 25.415089819208532
# Finish 228 epoch(es)
# step 229 - loss 23.956939697265625 - moving ave loss 25.26927480701424
# Finish 229 epoch(es)
# step 230 - loss 24.609455108642578 - moving ave loss 25.203292837177074
# Finish 230 epoch(es)
# step 231 - loss 25.452877044677734 - moving ave loss 25.22825125792714
# Finish 231 epoch(es)
# step 232 - loss 23.792842864990234 - moving ave loss 25.08471041863345
# Finish 232 epoch(es)
# step 233 - loss 24.210742950439453 - moving ave loss 24.997313671814048
# Finish 233 epoch(es)
# step 234 - loss 23.11041259765625 - moving ave loss 24.808623564398268
# Finish 234 epoch(es)
# step 235 - loss 23.51220703125 - moving ave loss 24.678981911083444
# Finish 235 epoch(es)
# step 236 - loss 24.570938110351562 - moving ave loss 24.668177531010258
# Finish 236 epoch(es)
# step 237 - loss 24.00341796875 - moving ave loss 24.601701574784233
# Finish 237 epoch(es)
# step 238 - loss 22.97174072265625 - moving ave loss 24.438705489571436
# Finish 238 epoch(es)
# step 239 - loss 21.62188720703125 - moving ave loss 24.157023661317417
# Finish 239 epoch(es)
# step 240 - loss 22.93000602722168 - moving ave loss 24.034321897907844
# Finish 240 epoch(es)
# step 241 - loss 24.312583923339844 - moving ave loss 24.062148100451044
# Finish 241 epoch(es)
# step 242 - loss 21.75423240661621 - moving ave loss 23.831356531067563
# Finish 242 epoch(es)
# step 243 - loss 24.096309661865234 - moving ave loss 23.85785184414733
# Finish 243 epoch(es)
# step 244 - loss 23.063541412353516 - moving ave loss 23.77842080096795
# Finish 244 epoch(es)
# step 245 - loss 21.51446533203125 - moving ave loss 23.55202525407428
# Finish 245 epoch(es)
# step 246 - loss 21.257091522216797 - moving ave loss 23.322531880888533
# Finish 246 epoch(es)
# step 247 - loss 22.842805862426758 - moving ave loss 23.274559279042357
# Finish 247 epoch(es)
# step 248 - loss 22.923601150512695 - moving ave loss 23.23946346618939
# Finish 248 epoch(es)
# step 249 - loss 23.677906036376953 - moving ave loss 23.283307723208146
# Finish 249 epoch(es)
# step 250 - loss 21.263282775878906 - moving ave loss 23.081305228475223
# Checkpoint at step 250
# Finish 250 epoch(es)
# step 251 - loss 23.175209045410156 - moving ave loss 23.09069561016872
# Finish 251 epoch(es)
# step 252 - loss 21.610267639160156 - moving ave loss 22.942652813067863
# Finish 252 epoch(es)
# step 253 - loss 22.593624114990234 - moving ave loss 22.9077499432601
# Finish 253 epoch(es)
# step 254 - loss 21.80921173095703 - moving ave loss 22.797896122029794
# Finish 254 epoch(es)
# step 255 - loss 22.404834747314453 - moving ave loss 22.75858998455826
# Finish 255 epoch(es)
# step 256 - loss 22.91167449951172 - moving ave loss 22.773898436053607
# Finish 256 epoch(es)
# step 257 - loss 22.205190658569336 - moving ave loss 22.71702765830518
# Finish 257 epoch(es)
# step 258 - loss 21.55175018310547 - moving ave loss 22.60049991078521
# Finish 258 epoch(es)
# step 259 - loss 21.739103317260742 - moving ave loss 22.514360251432763
# Finish 259 epoch(es)
# step 260 - loss 23.236087799072266 - moving ave loss 22.586533006196714
# Finish 260 epoch(es)
# step 261 - loss 22.72092628479004 - moving ave loss 22.599972334056048
# Finish 261 epoch(es)
# step 262 - loss 19.849563598632812 - moving ave loss 22.324931460513728
# Finish 262 epoch(es)
# step 263 - loss 23.19881820678711 - moving ave loss 22.412320135141066
# Finish 263 epoch(es)
# step 264 - loss 21.27263832092285 - moving ave loss 22.298351953719244
# Finish 264 epoch(es)
# step 265 - loss 22.38360595703125 - moving ave loss 22.306877354050446
# Finish 265 epoch(es)
# step 266 - loss 20.784273147583008 - moving ave loss 22.1546169334037
# Finish 266 epoch(es)
# step 267 - loss 20.441986083984375 - moving ave loss 21.98335384846177
# Finish 267 epoch(es)
# step 268 - loss 20.334747314453125 - moving ave loss 21.818493195060906
# Finish 268 epoch(es)
# step 269 - loss 24.115100860595703 - moving ave loss 22.04815396161439
# Finish 269 epoch(es)
# step 270 - loss 21.71173095703125 - moving ave loss 22.014511661156074
# Finish 270 epoch(es)
# step 271 - loss 20.13612174987793 - moving ave loss 21.82667267002826
# Finish 271 epoch(es)
# step 272 - loss 20.63503074645996 - moving ave loss 21.707508477671432
# Finish 272 epoch(es)
# step 273 - loss 18.790908813476562 - moving ave loss 21.415848511251948
# Finish 273 epoch(es)
# step 274 - loss 22.214021682739258 - moving ave loss 21.49566582840068
# Finish 274 epoch(es)
# step 275 - loss 24.149574279785156 - moving ave loss 21.76105667353913
# Finish 275 epoch(es)
# step 276 - loss 19.511035919189453 - moving ave loss 21.536054598104162
# Finish 276 epoch(es)
# step 277 - loss 19.313512802124023 - moving ave loss 21.31380041850615
# Finish 277 epoch(es)
# step 278 - loss 21.193336486816406 - moving ave loss 21.301754025337175
# Finish 278 epoch(es)
# step 279 - loss 19.152189254760742 - moving ave loss 21.086797548279534
# Finish 279 epoch(es)
# step 280 - loss 21.783676147460938 - moving ave loss 21.156485408197675
# Finish 280 epoch(es)
# step 281 - loss 18.63966941833496 - moving ave loss 20.904803809211405
# Finish 281 epoch(es)
# step 282 - loss 20.519367218017578 - moving ave loss 20.866260150092025
# Finish 282 epoch(es)
# step 283 - loss 23.357643127441406 - moving ave loss 21.115398447826962
# Finish 283 epoch(es)
# step 284 - loss 18.59748077392578 - moving ave loss 20.863606680436845
# Finish 284 epoch(es)
# step 285 - loss 17.700458526611328 - moving ave loss 20.547291865054294
# Finish 285 epoch(es)
# step 286 - loss 19.186994552612305 - moving ave loss 20.411262133810094
# Finish 286 epoch(es)
# step 287 - loss 19.408966064453125 - moving ave loss 20.3110325268744
# Finish 287 epoch(es)
# step 288 - loss 18.96830177307129 - moving ave loss 20.17675945149409
# Finish 288 epoch(es)
# step 289 - loss 19.843318939208984 - moving ave loss 20.143415400265578
# Finish 289 epoch(es)
# step 290 - loss 19.726591110229492 - moving ave loss 20.10173297126197
# Finish 290 epoch(es)
# step 291 - loss 19.51261329650879 - moving ave loss 20.042821003786653
# Finish 291 epoch(es)
# step 292 - loss 20.367755889892578 - moving ave loss 20.075314492397247
# Finish 292 epoch(es)
# step 293 - loss 18.201982498168945 - moving ave loss 19.887981292974416
# Finish 293 epoch(es)
# step 294 - loss 19.522186279296875 - moving ave loss 19.851401791606666
# Finish 294 epoch(es)
# step 295 - loss 17.661985397338867 - moving ave loss 19.632460152179885
# Finish 295 epoch(es)
# step 296 - loss 17.76504135131836 - moving ave loss 19.445718272093735
# Finish 296 epoch(es)
# step 297 - loss 18.365039825439453 - moving ave loss 19.337650427428308
# Finish 297 epoch(es)
# step 298 - loss 19.846115112304688 - moving ave loss 19.388496895915946
# Finish 298 epoch(es)
# step 299 - loss 18.264415740966797 - moving ave loss 19.27608878042103
# Finish 299 epoch(es)
# step 300 - loss 17.544286727905273 - moving ave loss 19.102908575169455
# Finish 300 epoch(es)
# step 301 - loss 18.942626953125 - moving ave loss 19.08688041296501
# Finish 301 epoch(es)
# step 302 - loss 17.32574462890625 - moving ave loss 18.910766834559134
# Finish 302 epoch(es)
# step 303 - loss 19.292308807373047 - moving ave loss 18.948921031840523
# Finish 303 epoch(es)
# step 304 - loss 17.140918731689453 - moving ave loss 18.768120801825418
# Finish 304 epoch(es)
# step 305 - loss 17.991474151611328 - moving ave loss 18.69045613680401
# Finish 305 epoch(es)
# step 306 - loss 19.004169464111328 - moving ave loss 18.721827469534745
# Finish 306 epoch(es)
# step 307 - loss 16.55109977722168 - moving ave loss 18.50475470030344
# Finish 307 epoch(es)
# step 308 - loss 15.906867027282715 - moving ave loss 18.244965933001367
# Finish 308 epoch(es)
# step 309 - loss 16.859872817993164 - moving ave loss 18.10645662150055
# Finish 309 epoch(es)
# step 310 - loss 16.241819381713867 - moving ave loss 17.91999289752188
# Finish 310 epoch(es)
# step 311 - loss 18.457443237304688 - moving ave loss 17.97373793150016
# Finish 311 epoch(es)
# step 312 - loss 18.293426513671875 - moving ave loss 18.005706789717333
# Finish 312 epoch(es)
# step 313 - loss 15.553898811340332 - moving ave loss 17.760525991879632
# Finish 313 epoch(es)
# step 314 - loss 16.31846046447754 - moving ave loss 17.616319439139424
# Finish 314 epoch(es)
# step 315 - loss 16.656982421875 - moving ave loss 17.520385737412983
# Finish 315 epoch(es)
# step 316 - loss 16.1529483795166 - moving ave loss 17.383642001623343
# Finish 316 epoch(es)
# step 317 - loss 18.35886001586914 - moving ave loss 17.481163803047924
# Finish 317 epoch(es)
# step 318 - loss 16.549724578857422 - moving ave loss 17.388019880628875
# Finish 318 epoch(es)
# step 319 - loss 18.883325576782227 - moving ave loss 17.53755045024421
# Finish 319 epoch(es)
# step 320 - loss 16.398887634277344 - moving ave loss 17.423684168647526
# Finish 320 epoch(es)
# step 321 - loss 16.26706314086914 - moving ave loss 17.30802206586969
# Finish 321 epoch(es)
# step 322 - loss 15.292342185974121 - moving ave loss 17.106454077880134
# Finish 322 epoch(es)
# step 323 - loss 15.21683120727539 - moving ave loss 16.91749179081966
# Finish 323 epoch(es)
# step 324 - loss 15.39494514465332 - moving ave loss 16.765237126203026
# Finish 324 epoch(es)
# step 325 - loss 17.495811462402344 - moving ave loss 16.83829455982296
# Finish 325 epoch(es)
# step 326 - loss 14.811553001403809 - moving ave loss 16.635620403981044
# Finish 326 epoch(es)
# step 327 - loss 18.998998641967773 - moving ave loss 16.871958227779718
# Finish 327 epoch(es)
# step 328 - loss 14.859007835388184 - moving ave loss 16.670663188540566
# Finish 328 epoch(es)
# step 329 - loss 14.449726104736328 - moving ave loss 16.448569480160142
# Finish 329 epoch(es)
# step 330 - loss 17.602689743041992 - moving ave loss 16.56398150644833
# Finish 330 epoch(es)
# step 331 - loss 18.111379623413086 - moving ave loss 16.718721318144805
# Finish 331 epoch(es)
# step 332 - loss 16.360933303833008 - moving ave loss 16.682942516713627
# Finish 332 epoch(es)
# step 333 - loss 15.809793472290039 - moving ave loss 16.59562761227127
# Finish 333 epoch(es)
# step 334 - loss 14.27346420288086 - moving ave loss 16.36341127133223
# Finish 334 epoch(es)
# step 335 - loss 15.855850219726562 - moving ave loss 16.312655166171663
# Finish 335 epoch(es)
# step 336 - loss 15.93039321899414 - moving ave loss 16.27442897145391
# Finish 336 epoch(es)
# step 337 - loss 14.29987621307373 - moving ave loss 16.076973695615894
# Finish 337 epoch(es)
# step 338 - loss 13.712040901184082 - moving ave loss 15.840480416172714
# Finish 338 epoch(es)
# step 339 - loss 15.820745468139648 - moving ave loss 15.838506921369408
# Finish 339 epoch(es)
# step 340 - loss 14.893837928771973 - moving ave loss 15.744040022109665
# Finish 340 epoch(es)
# step 341 - loss 15.06263256072998 - moving ave loss 15.675899275971696
# Finish 341 epoch(es)
# step 342 - loss 13.866701126098633 - moving ave loss 15.494979460984391
# Finish 342 epoch(es)
# step 343 - loss 16.22899627685547 - moving ave loss 15.568381142571498
# Finish 343 epoch(es)
# step 344 - loss 16.08981704711914 - moving ave loss 15.620524733026262
# Finish 344 epoch(es)
# step 345 - loss 14.443334579467773 - moving ave loss 15.502805717670414
# Finish 345 epoch(es)
# step 346 - loss 14.453618049621582 - moving ave loss 15.39788695086553
# Finish 346 epoch(es)
# step 347 - loss 14.92519474029541 - moving ave loss 15.350617729808517
# Finish 347 epoch(es)
# step 348 - loss 14.271825790405273 - moving ave loss 15.242738535868193
# Finish 348 epoch(es)
# step 349 - loss 12.444841384887695 - moving ave loss 14.962948820770144
# Finish 349 epoch(es)
# step 350 - loss 15.655475616455078 - moving ave loss 15.032201500338637
# Finish 350 epoch(es)
# step 351 - loss 14.27159309387207 - moving ave loss 14.95614065969198
# Finish 351 epoch(es)
# step 352 - loss 14.39011287689209 - moving ave loss 14.899537881411991
# Finish 352 epoch(es)
# step 353 - loss 13.119834899902344 - moving ave loss 14.721567583261027
# Finish 353 epoch(es)
# step 354 - loss 13.313749313354492 - moving ave loss 14.580785756270375
# Finish 354 epoch(es)
# step 355 - loss 13.70013427734375 - moving ave loss 14.492720608377713
# Finish 355 epoch(es)
# step 356 - loss 15.481427192687988 - moving ave loss 14.591591266808742
# Finish 356 epoch(es)
# step 357 - loss 14.8563232421875 - moving ave loss 14.618064464346618
# Finish 357 epoch(es)
# step 358 - loss 13.505766868591309 - moving ave loss 14.506834704771089
# Finish 358 epoch(es)
# step 359 - loss 13.171175956726074 - moving ave loss 14.373268829966587
# Finish 359 epoch(es)
# step 360 - loss 12.968564987182617 - moving ave loss 14.232798445688191
# Finish 360 epoch(es)
# step 361 - loss 12.5201997756958 - moving ave loss 14.061538578688952
# Finish 361 epoch(es)
# step 362 - loss 14.834770202636719 - moving ave loss 14.138861741083728
# Finish 362 epoch(es)
# step 363 - loss 14.032143592834473 - moving ave loss 14.128189926258804
# Finish 363 epoch(es)
# step 364 - loss 12.893315315246582 - moving ave loss 14.004702465157582
# Finish 364 epoch(es)
# step 365 - loss 13.825845718383789 - moving ave loss 13.986816790480203
# Finish 365 epoch(es)
# step 366 - loss 11.65158462524414 - moving ave loss 13.753293573956597
# Finish 366 epoch(es)
# step 367 - loss 15.012998580932617 - moving ave loss 13.8792640746542
# Finish 367 epoch(es)
# step 368 - loss 14.31634521484375 - moving ave loss 13.922972188673155
# Finish 368 epoch(es)
# step 369 - loss 13.389330863952637 - moving ave loss 13.869608056201104
# Finish 369 epoch(es)
# step 370 - loss 12.871793746948242 - moving ave loss 13.769826625275819
# Finish 370 epoch(es)
# step 371 - loss 13.300910949707031 - moving ave loss 13.72293505771894
# Finish 371 epoch(es)
# step 372 - loss 13.413579940795898 - moving ave loss 13.691999546026636
# Finish 372 epoch(es)
# step 373 - loss 15.698166847229004 - moving ave loss 13.892616276146873
# Finish 373 epoch(es)
# step 374 - loss 15.175671577453613 - moving ave loss 14.020921806277547
# Finish 374 epoch(es)
# step 375 - loss 13.165823936462402 - moving ave loss 13.935412019296034
# Checkpoint at step 375
# Finish 375 epoch(es)
# step 376 - loss 14.918567657470703 - moving ave loss 14.033727583113503
# Finish 376 epoch(es)
# step 377 - loss 12.617899894714355 - moving ave loss 13.892144814273589
# Finish 377 epoch(es)
# step 378 - loss 13.738197326660156 - moving ave loss 13.876750065512246
# Finish 378 epoch(es)
# step 379 - loss 13.408992767333984 - moving ave loss 13.82997433569442
# Finish 379 epoch(es)
# step 380 - loss 13.989822387695312 - moving ave loss 13.84595914089451
# Finish 380 epoch(es)
# step 381 - loss 12.356449127197266 - moving ave loss 13.697008139524787
# Finish 381 epoch(es)
# step 382 - loss 12.945767402648926 - moving ave loss 13.6218840658372
# Finish 382 epoch(es)
# step 383 - loss 16.698673248291016 - moving ave loss 13.929562984082583
# Finish 383 epoch(es)
# step 384 - loss 13.239368438720703 - moving ave loss 13.860543529546396
# Finish 384 epoch(es)
# step 385 - loss 12.561044692993164 - moving ave loss 13.730593645891073
# Finish 385 epoch(es)
# step 386 - loss 12.786746978759766 - moving ave loss 13.636208979177942
# Finish 386 epoch(es)
# step 387 - loss 12.55929183959961 - moving ave loss 13.52851726522011
# Finish 387 epoch(es)
# step 388 - loss 11.852043151855469 - moving ave loss 13.360869853883647
# Finish 388 epoch(es)
# step 389 - loss 15.0910005569458 - moving ave loss 13.533882924189863
# Finish 389 epoch(es)
# step 390 - loss 11.690174102783203 - moving ave loss 13.349512042049197
# Finish 390 epoch(es)
# step 391 - loss 12.338103294372559 - moving ave loss 13.248371167281533
# Finish 391 epoch(es)
# step 392 - loss 12.806283950805664 - moving ave loss 13.204162445633948
# Finish 392 epoch(es)
# step 393 - loss 15.09852409362793 - moving ave loss 13.393598610433346
# Finish 393 epoch(es)
# step 394 - loss 12.729984283447266 - moving ave loss 13.327237177734737
# Finish 394 epoch(es)
# step 395 - loss 12.552835464477539 - moving ave loss 13.249797006409018
# Finish 395 epoch(es)
# step 396 - loss 11.52338981628418 - moving ave loss 13.077156287396535
# Finish 396 epoch(es)
# step 397 - loss 9.910407066345215 - moving ave loss 12.760481365291403
# Finish 397 epoch(es)
# step 398 - loss 11.444221496582031 - moving ave loss 12.628855378420466
# Finish 398 epoch(es)
# step 399 - loss 10.81309700012207 - moving ave loss 12.447279540590626
# Finish 399 epoch(es)
# step 400 - loss 11.947460174560547 - moving ave loss 12.397297603987619
# Finish 400 epoch(es)
# step 401 - loss 12.56421184539795 - moving ave loss 12.413989028128652
# Finish 401 epoch(es)
# step 402 - loss 10.348456382751465 - moving ave loss 12.207435763590935
# Finish 402 epoch(es)
# step 403 - loss 15.92962646484375 - moving ave loss 12.579654833716218
# Finish 403 epoch(es)
# step 404 - loss 12.427783966064453 - moving ave loss 12.56446774695104
# Finish 404 epoch(es)
# step 405 - loss 15.567033767700195 - moving ave loss 12.864724349025957
# Finish 405 epoch(es)
# step 406 - loss 13.727012634277344 - moving ave loss 12.950953177551096
# Finish 406 epoch(es)
# step 407 - loss 13.161726951599121 - moving ave loss 12.972030554955898
# Finish 407 epoch(es)
# step 408 - loss 10.331165313720703 - moving ave loss 12.707944030832378
# Finish 408 epoch(es)
# step 409 - loss 11.996030807495117 - moving ave loss 12.636752708498651
# Finish 409 epoch(es)
# step 410 - loss 11.445752143859863 - moving ave loss 12.517652652034773
# Finish 410 epoch(es)
# step 411 - loss 11.449972152709961 - moving ave loss 12.410884602102291
# Finish 411 epoch(es)
# step 412 - loss 9.29751205444336 - moving ave loss 12.099547347336399
# Finish 412 epoch(es)
# step 413 - loss 11.757950782775879 - moving ave loss 12.065387690880348
# Finish 413 epoch(es)
# step 414 - loss 9.847485542297363 - moving ave loss 11.84359747602205
# Finish 414 epoch(es)
# step 415 - loss 10.42645263671875 - moving ave loss 11.70188299209172
# Finish 415 epoch(es)
# step 416 - loss 11.938401222229004 - moving ave loss 11.725534815105448
# Finish 416 epoch(es)
# step 417 - loss 12.013004302978516 - moving ave loss 11.754281763892756
# Finish 417 epoch(es)
# step 418 - loss 12.59450912475586 - moving ave loss 11.838304499979067
# Finish 418 epoch(es)
# step 419 - loss 12.446149826049805 - moving ave loss 11.899089032586142
# Finish 419 epoch(es)
# step 420 - loss 9.918418884277344 - moving ave loss 11.701022017755262
# Finish 420 epoch(es)
# step 421 - loss 10.891021728515625 - moving ave loss 11.620021988831299
# Finish 421 epoch(es)
# step 422 - loss 9.246286392211914 - moving ave loss 11.382648429169361
# Finish 422 epoch(es)
# step 423 - loss 13.534464836120605 - moving ave loss 11.597830069864486
# Finish 423 epoch(es)
# step 424 - loss 10.294133186340332 - moving ave loss 11.46746038151207
# Finish 424 epoch(es)
# step 425 - loss 11.094979286193848 - moving ave loss 11.430212271980249
# Finish 425 epoch(es)
# step 426 - loss 13.799802780151367 - moving ave loss 11.667171322797362
# Finish 426 epoch(es)
# step 427 - loss 12.271129608154297 - moving ave loss 11.727567151333055
# Finish 427 epoch(es)
# step 428 - loss 9.678048133850098 - moving ave loss 11.52261524958476
# Finish 428 epoch(es)
# step 429 - loss 9.831259727478027 - moving ave loss 11.353479697374087
# Finish 429 epoch(es)
# step 430 - loss 9.671844482421875 - moving ave loss 11.185316175878867
# Finish 430 epoch(es)
# step 431 - loss 10.769600868225098 - moving ave loss 11.143744645113491
# Finish 431 epoch(es)
# step 432 - loss 10.787405014038086 - moving ave loss 11.108110682005952
# Finish 432 epoch(es)
# step 433 - loss 8.956369400024414 - moving ave loss 10.892936553807798
# Finish 433 epoch(es)
# step 434 - loss 13.05052375793457 - moving ave loss 11.108695274220475
# Finish 434 epoch(es)
# step 435 - loss 9.307640075683594 - moving ave loss 10.928589754366788
# Finish 435 epoch(es)
# step 436 - loss 12.511889457702637 - moving ave loss 11.086919724700373
# Finish 436 epoch(es)
# step 437 - loss 8.740431785583496 - moving ave loss 10.852270930788684
# Finish 437 epoch(es)
# step 438 - loss 8.552346229553223 - moving ave loss 10.622278460665138
# Finish 438 epoch(es)
# step 439 - loss 9.929061889648438 - moving ave loss 10.552956803563468
# Finish 439 epoch(es)
# step 440 - loss 12.271551132202148 - moving ave loss 10.724816236427337
# Finish 440 epoch(es)
# step 441 - loss 10.122198104858398 - moving ave loss 10.664554423270443
# Finish 441 epoch(es)
# step 442 - loss 10.413785934448242 - moving ave loss 10.639477574388224
# Finish 442 epoch(es)
# step 443 - loss 10.819818496704102 - moving ave loss 10.657511666619811
# Finish 443 epoch(es)
# step 444 - loss 9.798644065856934 - moving ave loss 10.571624906543525
# Finish 444 epoch(es)
# step 445 - loss 10.142891883850098 - moving ave loss 10.528751604274182
# Finish 445 epoch(es)
# step 446 - loss 13.516860961914062 - moving ave loss 10.827562540038171
# Finish 446 epoch(es)
# step 447 - loss 11.392862319946289 - moving ave loss 10.884092518028982
# Finish 447 epoch(es)
# step 448 - loss 9.378997802734375 - moving ave loss 10.733583046499522
# Finish 448 epoch(es)
# step 449 - loss 10.04959487915039 - moving ave loss 10.66518422976461
# Finish 449 epoch(es)
# step 450 - loss 11.073749542236328 - moving ave loss 10.706040761011781
# Finish 450 epoch(es)
# step 451 - loss 8.954538345336914 - moving ave loss 10.530890519444295
# Finish 451 epoch(es)
# step 452 - loss 12.39709758758545 - moving ave loss 10.717511226258411
# Finish 452 epoch(es)
# step 453 - loss 10.812766075134277 - moving ave loss 10.727036711145997
# Finish 453 epoch(es)
# step 454 - loss 8.8744535446167 - moving ave loss 10.541778394493068
# Finish 454 epoch(es)
# step 455 - loss 10.231597900390625 - moving ave loss 10.510760345082826
# Finish 455 epoch(es)
# step 456 - loss 10.796425819396973 - moving ave loss 10.539326892514241
# Finish 456 epoch(es)
# step 457 - loss 9.127764701843262 - moving ave loss 10.398170673447144
# Finish 457 epoch(es)
# step 458 - loss 10.009511947631836 - moving ave loss 10.359304800865614
# Finish 458 epoch(es)
# step 459 - loss 9.618829727172852 - moving ave loss 10.285257293496338
# Finish 459 epoch(es)
# step 460 - loss 10.453147888183594 - moving ave loss 10.302046352965064
# Finish 460 epoch(es)
# step 461 - loss 12.283931732177734 - moving ave loss 10.50023489088633
# Finish 461 epoch(es)
# step 462 - loss 11.098611831665039 - moving ave loss 10.560072584964203
# Finish 462 epoch(es)
# step 463 - loss 10.60628890991211 - moving ave loss 10.564694217458994
# Finish 463 epoch(es)
# step 464 - loss 8.246283531188965 - moving ave loss 10.332853148831992
# Finish 464 epoch(es)
# step 465 - loss 8.853952407836914 - moving ave loss 10.184963074732483
# Finish 465 epoch(es)
# step 466 - loss 9.755633354187012 - moving ave loss 10.142030102677937
# Finish 466 epoch(es)
# step 467 - loss 7.790607452392578 - moving ave loss 9.906887837649402
# Finish 467 epoch(es)
# step 468 - loss 8.480427742004395 - moving ave loss 9.764241828084902
# Finish 468 epoch(es)
# step 469 - loss 8.948726654052734 - moving ave loss 9.682690310681686
# Finish 469 epoch(es)
# step 470 - loss 8.675338745117188 - moving ave loss 9.581955154125236
# Finish 470 epoch(es)
# step 471 - loss 8.461491584777832 - moving ave loss 9.469908797190495
# Finish 471 epoch(es)
# step 472 - loss 9.491842269897461 - moving ave loss 9.472102144461193
# Finish 472 epoch(es)
# step 473 - loss 9.34121322631836 - moving ave loss 9.459013252646908
# Finish 473 epoch(es)
# step 474 - loss 8.144957542419434 - moving ave loss 9.32760768162416
# Finish 474 epoch(es)
# step 475 - loss 8.092487335205078 - moving ave loss 9.204095646982253
# Finish 475 epoch(es)
# step 476 - loss 9.385774612426758 - moving ave loss 9.222263543526704
# Finish 476 epoch(es)
# step 477 - loss 8.908111572265625 - moving ave loss 9.190848346400596
# Finish 477 epoch(es)
# step 478 - loss 8.659472465515137 - moving ave loss 9.13771075831205
# Finish 478 epoch(es)
# step 479 - loss 8.163684844970703 - moving ave loss 9.040308166977916
# Finish 479 epoch(es)
# step 480 - loss 8.153170585632324 - moving ave loss 8.951594408843357
# Finish 480 epoch(es)
# step 481 - loss 8.942170143127441 - moving ave loss 8.950651982271767
# Finish 481 epoch(es)
# step 482 - loss 9.220364570617676 - moving ave loss 8.97762324110636
# Finish 482 epoch(es)
# step 483 - loss 9.695960998535156 - moving ave loss 9.049457016849239
# Finish 483 epoch(es)
# step 484 - loss 10.666974067687988 - moving ave loss 9.211208721933115
# Finish 484 epoch(es)
# step 485 - loss 7.724888801574707 - moving ave loss 9.062576729897275
# Finish 485 epoch(es)
# step 486 - loss 10.033624649047852 - moving ave loss 9.159681521812333
# Finish 486 epoch(es)
# step 487 - loss 7.797752857208252 - moving ave loss 9.023488655351926
# Finish 487 epoch(es)
# step 488 - loss 7.857214450836182 - moving ave loss 8.906861234900353
# Finish 488 epoch(es)
# step 489 - loss 8.583866119384766 - moving ave loss 8.874561723348794
# Finish 489 epoch(es)
# step 490 - loss 8.794971466064453 - moving ave loss 8.86660269762036
# Finish 490 epoch(es)
# step 491 - loss 9.817718505859375 - moving ave loss 8.961714278444262
# Finish 491 epoch(es)
# step 492 - loss 9.441551208496094 - moving ave loss 9.009697971449446
# Finish 492 epoch(es)
# step 493 - loss 7.290031909942627 - moving ave loss 8.837731365298765
# Finish 493 epoch(es)
# step 494 - loss 8.797836303710938 - moving ave loss 8.833741859139984
# Finish 494 epoch(es)
# step 495 - loss 9.4599609375 - moving ave loss 8.896363766975986
# Finish 495 epoch(es)
# step 496 - loss 8.063990592956543 - moving ave loss 8.81312644957404
# Finish 496 epoch(es)
# step 497 - loss 7.5146331787109375 - moving ave loss 8.68327712248773
# Finish 497 epoch(es)
# step 498 - loss 8.757518768310547 - moving ave loss 8.690701287070013
# Finish 498 epoch(es)
# step 499 - loss 9.98311996459961 - moving ave loss 8.819943154822973
# Finish 499 epoch(es)
# step 500 - loss 6.965254306793213 - moving ave loss 8.634474270019997
# Checkpoint at step 500
# Finish 500 epoch(es)
# step 501 - loss 9.597227096557617 - moving ave loss 8.730749552673759
# Finish 501 epoch(es)
# step 502 - loss 9.878292083740234 - moving ave loss 8.845503805780407
# Finish 502 epoch(es)
# step 503 - loss 7.715063095092773 - moving ave loss 8.732459734711643
# Finish 503 epoch(es)
# step 504 - loss 8.367740631103516 - moving ave loss 8.69598782435083
# Finish 504 epoch(es)
# step 505 - loss 10.49902629852295 - moving ave loss 8.876291671768042
# Finish 505 epoch(es)
# step 506 - loss 8.60289192199707 - moving ave loss 8.848951696790945
# Finish 506 epoch(es)
# step 507 - loss 9.483173370361328 - moving ave loss 8.912373864147984
# Finish 507 epoch(es)
# step 508 - loss 7.424915313720703 - moving ave loss 8.763628009105258
# Finish 508 epoch(es)
# step 509 - loss 11.705343246459961 - moving ave loss 9.057799532840727
# Finish 509 epoch(es)
# step 510 - loss 7.837348937988281 - moving ave loss 8.935754473355482
# Finish 510 epoch(es)
# step 511 - loss 9.729512214660645 - moving ave loss 9.015130247485999
# Finish 511 epoch(es)
# step 512 - loss 10.586673736572266 - moving ave loss 9.172284596394626
# Finish 512 epoch(es)
# step 513 - loss 8.651739120483398 - moving ave loss 9.120230048803503
# Finish 513 epoch(es)
# step 514 - loss 9.137004852294922 - moving ave loss 9.121907529152645
# Finish 514 epoch(es)
# step 515 - loss 8.08237075805664 - moving ave loss 9.017953852043044
# Finish 515 epoch(es)
# step 516 - loss 7.152693748474121 - moving ave loss 8.831427841686153
# Finish 516 epoch(es)
# step 517 - loss 7.385123252868652 - moving ave loss 8.686797382804404
# Finish 517 epoch(es)
# step 518 - loss 8.555346488952637 - moving ave loss 8.673652293419227
# Finish 518 epoch(es)
# step 519 - loss 7.667611122131348 - moving ave loss 8.57304817629044
# Finish 519 epoch(es)
# step 520 - loss 8.020649909973145 - moving ave loss 8.517808349658711
# Finish 520 epoch(es)
# step 521 - loss 7.932613372802734 - moving ave loss 8.459288851973113
# Finish 521 epoch(es)
# ...
# Finish 826 epoch(es)
# step 827 - loss 7.319963455200195 - moving ave loss 6.968913151723184
# Finish 827 epoch(es)
# step 828 - loss 7.7170562744140625 - moving ave loss 7.043727463992272
# Finish 828 epoch(es)
# step 829 - loss 6.980544090270996 - moving ave loss 7.037409126620144
# Finish 829 epoch(es)
# step 830 - loss 5.1639556884765625 - moving ave loss 6.850063782805786
# Finish 830 epoch(es)
# step 831 - loss 7.1637163162231445 - moving ave loss 6.881429036147521
# Finish 831 epoch(es)
# step 832 - loss 8.488265037536621 - moving ave loss 7.042112636286431
# Finish 832 epoch(es)
# step 833 - loss 9.581336975097656 - moving ave loss 7.296035070167553
# Finish 833 epoch(es)
# step 834 - loss 9.314863204956055 - moving ave loss 7.497917883646404
# Finish 834 epoch(es)
# step 835 - loss 5.61051607131958 - moving ave loss 7.309177702413722
# Finish 835 epoch(es)
# step 836 - loss 7.492966651916504 - moving ave loss 7.3275565973640004
# Finish 836 epoch(es)
# step 837 - loss 7.294206619262695 - moving ave loss 7.32422159955387
# Finish 837 epoch(es)
# step 838 - loss 6.5472259521484375 - moving ave loss 7.246522034813327
# Finish 838 epoch(es)
# step 839 - loss 7.472989559173584 - moving ave loss 7.2691687872493524
# Finish 839 epoch(es)
# step 840 - loss 7.447040557861328 - moving ave loss 7.28695596431055
# Finish 840 epoch(es)
# step 841 - loss 8.315356254577637 - moving ave loss 7.389795993337259
# Finish 841 epoch(es)
# step 842 - loss 6.381863594055176 - moving ave loss 7.289002753409052
# Finish 842 epoch(es)
# step 843 - loss 6.314814567565918 - moving ave loss 7.191583934824738
# Finish 843 epoch(es)
# step 844 - loss 8.065180778503418 - moving ave loss 7.2789436191926065
# Finish 844 epoch(es)
# step 845 - loss 7.065690994262695 - moving ave loss 7.2576183566996155
# Finish 845 epoch(es)
# step 846 - loss 6.847682952880859 - moving ave loss 7.21662481631774
# Finish 846 epoch(es)
# step 847 - loss 11.018840789794922 - moving ave loss 7.5968464136654585
# Finish 847 epoch(es)
# step 848 - loss 7.223074913024902 - moving ave loss 7.559469263601403
# Finish 848 epoch(es)
# step 849 - loss 7.877574920654297 - moving ave loss 7.591279829306693
# Finish 849 epoch(es)
# step 850 - loss 7.477786540985107 - moving ave loss 7.579930500474535
# Finish 850 epoch(es)
# step 851 - loss 6.32918643951416 - moving ave loss 7.454856094378497
# Finish 851 epoch(es)
# step 852 - loss 8.361456871032715 - moving ave loss 7.545516172043919
# Finish 852 epoch(es)
# step 853 - loss 6.508543968200684 - moving ave loss 7.441818951659595
# Finish 853 epoch(es)
# step 854 - loss 10.371522903442383 - moving ave loss 7.734789346837874
# Finish 854 epoch(es)
# step 855 - loss 7.086384296417236 - moving ave loss 7.669948841795811
# Finish 855 epoch(es)
# step 856 - loss 6.651262283325195 - moving ave loss 7.56808018594875
# Finish 856 epoch(es)
# step 857 - loss 7.332085609436035 - moving ave loss 7.544480728297479
# Finish 857 epoch(es)
# step 858 - loss 6.63627815246582 - moving ave loss 7.453660470714314
# Finish 858 epoch(es)
# step 859 - loss 10.071087837219238 - moving ave loss 7.7154032073648064
# Finish 859 epoch(es)
# step 860 - loss 10.82415771484375 - moving ave loss 8.0262786581127
# Finish 860 epoch(es)
# step 861 - loss 10.377365112304688 - moving ave loss 8.2613873035319
# Finish 861 epoch(es)
# step 862 - loss 8.855944633483887 - moving ave loss 8.320843036527098
# Finish 862 epoch(es)
# step 863 - loss 8.237709045410156 - moving ave loss 8.312529637415404
# Finish 863 epoch(es)
# step 864 - loss 9.08380126953125 - moving ave loss 8.38965680062699
# Finish 864 epoch(es)
# step 865 - loss 9.633074760437012 - moving ave loss 8.513998596607992
# Finish 865 epoch(es)
# step 866 - loss 8.976224899291992 - moving ave loss 8.560221226876392
# Finish 866 epoch(es)
# step 867 - loss 8.009868621826172 - moving ave loss 8.50518596637137
# Finish 867 epoch(es)
# step 868 - loss 5.401261329650879 - moving ave loss 8.194793502699321
# Finish 868 epoch(es)
# step 869 - loss 8.327619552612305 - moving ave loss 8.20807610769062
# Finish 869 epoch(es)
# step 870 - loss 8.401605606079102 - moving ave loss 8.227429057529468
# Finish 870 epoch(es)
# step 871 - loss 7.80463171005249 - moving ave loss 8.18514932278177
# Finish 871 epoch(es)
# step 872 - loss 7.078765869140625 - moving ave loss 8.074510977417656
# Finish 872 epoch(es)
# step 873 - loss 8.306876182556152 - moving ave loss 8.097747497931506
# Finish 873 epoch(es)
# step 874 - loss 6.43345832824707 - moving ave loss 7.931318580963063
# Finish 874 epoch(es)
# step 875 - loss 7.723934650421143 - moving ave loss 7.910580187908871
# Checkpoint at step 875
# Finish 875 epoch(es)
# step 876 - loss 9.235807418823242 - moving ave loss 8.04310291100031
# Finish 876 epoch(es)
# step 877 - loss 6.5094146728515625 - moving ave loss 7.889734087185435
# Finish 877 epoch(es)
# step 878 - loss 7.245488166809082 - moving ave loss 7.8253094951478
# Finish 878 epoch(es)
# step 879 - loss 9.834182739257812 - moving ave loss 8.026196819558802
# Finish 879 epoch(es)
# step 880 - loss 6.507537841796875 - moving ave loss 7.874330921782609
# Finish 880 epoch(es)
# step 881 - loss 8.48690414428711 - moving ave loss 7.93558824403306
# Finish 881 epoch(es)
# step 882 - loss 9.852783203125 - moving ave loss 8.127307739942253
# Finish 882 epoch(es)
# step 883 - loss 7.644469261169434 - moving ave loss 8.07902389206497
# Finish 883 epoch(es)
# step 884 - loss 8.466033935546875 - moving ave loss 8.117724896413161
# Finish 884 epoch(es)
# step 885 - loss 5.00836181640625 - moving ave loss 7.80678858841247
# Finish 885 epoch(es)
# step 886 - loss 6.519548416137695 - moving ave loss 7.678064571184993
# Finish 886 epoch(es)
# step 887 - loss 7.4966864585876465 - moving ave loss 7.659926759925258
# Finish 887 epoch(es)
# step 888 - loss 8.511157035827637 - moving ave loss 7.745049787515496
# Finish 888 epoch(es)
# step 889 - loss 7.369757175445557 - moving ave loss 7.707520526308502
# Finish 889 epoch(es)
# step 890 - loss 7.653592109680176 - moving ave loss 7.70212768464567
# Finish 890 epoch(es)
# step 891 - loss 7.383394241333008 - moving ave loss 7.670254340314404
# Finish 891 epoch(es)
# step 892 - loss 10.631758689880371 - moving ave loss 7.966404775271001
# Finish 892 epoch(es)
# step 893 - loss 7.812699317932129 - moving ave loss 7.951034229537115
# Finish 893 epoch(es)
# step 894 - loss 7.444536209106445 - moving ave loss 7.900384427494048
# Finish 894 epoch(es)
# step 895 - loss 10.889863014221191 - moving ave loss 8.199332286166763
# Finish 895 epoch(es)
# step 896 - loss 8.075057029724121 - moving ave loss 8.186904760522498
# Finish 896 epoch(es)
# step 897 - loss 6.708435535430908 - moving ave loss 8.03905783801334
# Finish 897 epoch(es)
# step 898 - loss 7.4845733642578125 - moving ave loss 7.983609390637788
# Finish 898 epoch(es)
# step 899 - loss 9.907073974609375 - moving ave loss 8.175955849034947
# Finish 899 epoch(es)
# step 900 - loss 7.928375244140625 - moving ave loss 8.151197788545515
# Finish 900 epoch(es)
# step 901 - loss 9.569040298461914 - moving ave loss 8.292982039537154
# Finish 901 epoch(es)
# step 902 - loss 9.893359184265137 - moving ave loss 8.453019754009953
# Finish 902 epoch(es)
# step 903 - loss 8.805535316467285 - moving ave loss 8.488271310255687
# Finish 903 epoch(es)
# step 904 - loss 8.873270034790039 - moving ave loss 8.526771182709123
# Finish 904 epoch(es)
# step 905 - loss 6.247641086578369 - moving ave loss 8.298858173096047
# Finish 905 epoch(es)
# step 906 - loss 5.939755439758301 - moving ave loss 8.062947899762271
# Finish 906 epoch(es)
# step 907 - loss 10.329923629760742 - moving ave loss 8.289645472762118
# Finish 907 epoch(es)
# step 908 - loss 8.992481231689453 - moving ave loss 8.359929048654852
# Finish 908 epoch(es)
# step 909 - loss 8.376285552978516 - moving ave loss 8.361564699087218
# Finish 909 epoch(es)
# step 910 - loss 7.4514923095703125 - moving ave loss 8.270557460135528
# Finish 910 epoch(es)
# step 911 - loss 7.725373268127441 - moving ave loss 8.216039040934719
# Finish 911 epoch(es)
# step 912 - loss 6.981159687042236 - moving ave loss 8.092551105545471
# Finish 912 epoch(es)
# step 913 - loss 5.286503791809082 - moving ave loss 7.811946374171832
# Finish 913 epoch(es)
# step 914 - loss 10.082528114318848 - moving ave loss 8.039004548186533
# Finish 914 epoch(es)
# step 915 - loss 6.879117012023926 - moving ave loss 7.923015794570272
# Finish 915 epoch(es)
# step 916 - loss 6.628987789154053 - moving ave loss 7.79361299402865
# Finish 916 epoch(es)
# step 917 - loss 8.87053394317627 - moving ave loss 7.901305088943412
# Finish 917 epoch(es)
# step 918 - loss 7.829704284667969 - moving ave loss 7.894145008515868
# Finish 918 epoch(es)
# step 919 - loss 13.254654884338379 - moving ave loss 8.430195996098119
# Finish 919 epoch(es)
# step 920 - loss 9.359769821166992 - moving ave loss 8.523153378605006
# Finish 920 epoch(es)
# step 921 - loss 8.553701400756836 - moving ave loss 8.52620818082019
# Finish 921 epoch(es)
# step 922 - loss 10.197450637817383 - moving ave loss 8.693332426519909
# Finish 922 epoch(es)
# step 923 - loss 8.996570587158203 - moving ave loss 8.723656242583738
# Finish 923 epoch(es)
# step 924 - loss 7.192370414733887 - moving ave loss 8.570527659798753
# Finish 924 epoch(es)
# step 925 - loss 8.819587707519531 - moving ave loss 8.59543366457083
# Finish 925 epoch(es)
# step 926 - loss 6.20975399017334 - moving ave loss 8.35686569713108
# Finish 926 epoch(es)
# step 927 - loss 6.50233268737793 - moving ave loss 8.171412396155766
# Finish 927 epoch(es)
# step 928 - loss 8.515007972717285 - moving ave loss 8.205771953811919
# Finish 928 epoch(es)
# step 929 - loss 8.24116325378418 - moving ave loss 8.209311083809146
# Finish 929 epoch(es)
# step 930 - loss 7.250161647796631 - moving ave loss 8.113396140207895
# Finish 930 epoch(es)
# step 931 - loss 6.363887310028076 - moving ave loss 7.938445257189914
# Finish 931 epoch(es)
# step 932 - loss 8.243391990661621 - moving ave loss 7.9689399305370845
# Finish 932 epoch(es)
# step 933 - loss 6.980605125427246 - moving ave loss 7.870106450026101
# Finish 933 epoch(es)
# step 934 - loss 9.297770500183105 - moving ave loss 8.0128728550418
# Finish 934 epoch(es)
# step 935 - loss 9.52077579498291 - moving ave loss 8.163663149035912
# Finish 935 epoch(es)
# step 936 - loss 7.572378635406494 - moving ave loss 8.104534697672971
# Finish 936 epoch(es)
# step 937 - loss 7.5285539627075195 - moving ave loss 8.046936624176427
# Finish 937 epoch(es)
# step 938 - loss 7.341823577880859 - moving ave loss 7.97642531954687
# Finish 938 epoch(es)
# step 939 - loss 6.381176948547363 - moving ave loss 7.816900482446919
# Finish 939 epoch(es)
# step 940 - loss 5.866856098175049 - moving ave loss 7.621896044019732
# Finish 940 epoch(es)
# step 941 - loss 10.206009864807129 - moving ave loss 7.880307426098472
# Finish 941 epoch(es)
# step 942 - loss 11.144027709960938 - moving ave loss 8.206679454484718
# Finish 942 epoch(es)
# step 943 - loss 9.557256698608398 - moving ave loss 8.341737178897086
# Finish 943 epoch(es)
# step 944 - loss 8.315292358398438 - moving ave loss 8.33909269684722
# Finish 944 epoch(es)
# step 945 - loss 7.0550432205200195 - moving ave loss 8.2106877492145
# Finish 945 epoch(es)
# step 946 - loss 8.57765007019043 - moving ave loss 8.247383981312094
# Finish 946 epoch(es)
# step 947 - loss 7.219098091125488 - moving ave loss 8.144555392293434
# Finish 947 epoch(es)
# step 948 - loss 6.118966102600098 - moving ave loss 7.9419964633241005
# Finish 948 epoch(es)
# step 949 - loss 11.392853736877441 - moving ave loss 8.287082190679435
# Finish 949 epoch(es)
# step 950 - loss 7.276895523071289 - moving ave loss 8.186063523918621
# Finish 950 epoch(es)
# step 951 - loss 8.069210052490234 - moving ave loss 8.174378176775782
# Finish 951 epoch(es)
# step 952 - loss 7.872268199920654 - moving ave loss 8.14416717909027
# Finish 952 epoch(es)
# step 953 - loss 10.854700088500977 - moving ave loss 8.41522047003134
# Finish 953 epoch(es)
# step 954 - loss 6.8275146484375 - moving ave loss 8.256449887871955
# Finish 954 epoch(es)
# step 955 - loss 9.710302352905273 - moving ave loss 8.401835134375286
# Finish 955 epoch(es)
# step 956 - loss 6.248968601226807 - moving ave loss 8.186548481060438
# Finish 956 epoch(es)
# step 957 - loss 7.072913646697998 - moving ave loss 8.075184997624195
# Finish 957 epoch(es)
# step 958 - loss 10.188941955566406 - moving ave loss 8.286560693418416
# Finish 958 epoch(es)
# step 959 - loss 8.751935005187988 - moving ave loss 8.333098124595374
# Finish 959 epoch(es)
# step 960 - loss 9.306746482849121 - moving ave loss 8.43046296042075
# Finish 960 epoch(es)
# step 961 - loss 8.195793151855469 - moving ave loss 8.406995979564222
# Finish 961 epoch(es)
# step 962 - loss 8.126016616821289 - moving ave loss 8.37889804328993
# Finish 962 epoch(es)
# step 963 - loss 12.149201393127441 - moving ave loss 8.755928378273682
# Finish 963 epoch(es)
# step 964 - loss 6.896309852600098 - moving ave loss 8.569966525706324
# Finish 964 epoch(es)
# step 965 - loss 8.559957504272461 - moving ave loss 8.568965623562939
# Finish 965 epoch(es)
# step 966 - loss 6.351014137268066 - moving ave loss 8.347170474933451
# Finish 966 epoch(es)
# step 967 - loss 8.479488372802734 - moving ave loss 8.36040226472038
# Finish 967 epoch(es)
# step 968 - loss 7.348442554473877 - moving ave loss 8.25920629369573
# Finish 968 epoch(es)
# step 969 - loss 8.912816047668457 - moving ave loss 8.324567269093002
# Finish 969 epoch(es)
# step 970 - loss 10.700992584228516 - moving ave loss 8.562209800606553
# Finish 970 epoch(es)
# step 971 - loss 9.15512466430664 - moving ave loss 8.621501286976562
# Finish 971 epoch(es)
# step 972 - loss 7.215182781219482 - moving ave loss 8.480869436400855
# Finish 972 epoch(es)
# step 973 - loss 7.93392276763916 - moving ave loss 8.426174769524685
# Finish 973 epoch(es)
# step 974 - loss 7.573971748352051 - moving ave loss 8.340954467407421
# Finish 974 epoch(es)
# step 975 - loss 6.929359436035156 - moving ave loss 8.199794964270195
# Finish 975 epoch(es)
# step 976 - loss 6.434288501739502 - moving ave loss 8.023244318017126
# Finish 976 epoch(es)
# step 977 - loss 7.342191696166992 - moving ave loss 7.955139055832113
# Finish 977 epoch(es)
# step 978 - loss 6.506755828857422 - moving ave loss 7.810300733134644
# Finish 978 epoch(es)
# step 979 - loss 6.126898765563965 - moving ave loss 7.641960536377577
# Finish 979 epoch(es)
# step 980 - loss 7.8352370262146 - moving ave loss 7.66128818536128
# Finish 980 epoch(es)
# step 981 - loss 8.193857192993164 - moving ave loss 7.714545086124469
# Finish 981 epoch(es)
# step 982 - loss 11.195337295532227 - moving ave loss 8.062624307065244
# Finish 982 epoch(es)
# step 983 - loss 5.955379962921143 - moving ave loss 7.851899872650834
# Finish 983 epoch(es)
# step 984 - loss 7.161987781524658 - moving ave loss 7.782908663538217
# Finish 984 epoch(es)
# step 985 - loss 9.002786636352539 - moving ave loss 7.90489646081965
# Finish 985 epoch(es)
# step 986 - loss 7.937338829040527 - moving ave loss 7.908140697641738
# Finish 986 epoch(es)
# step 987 - loss 8.171276092529297 - moving ave loss 7.9344542371304945
# Finish 987 epoch(es)
# step 988 - loss 8.617947578430176 - moving ave loss 8.002803571260463
# Finish 988 epoch(es)
# step 989 - loss 7.86348295211792 - moving ave loss 7.988871509346209
# Finish 989 epoch(es)
# step 990 - loss 9.654631614685059 - moving ave loss 8.155447519880095
# Finish 990 epoch(es)
# step 991 - loss 8.960697174072266 - moving ave loss 8.235972485299312
# Finish 991 epoch(es)
# step 992 - loss 8.505918502807617 - moving ave loss 8.262967087050143
# Finish 992 epoch(es)
# step 993 - loss 6.308546543121338 - moving ave loss 8.067525032657263
# Finish 993 epoch(es)
# step 994 - loss 6.607041358947754 - moving ave loss 7.9214766652863124
# Finish 994 epoch(es)
# step 995 - loss 7.547900199890137 - moving ave loss 7.884119018746695
# Finish 995 epoch(es)
# step 996 - loss 7.210577011108398 - moving ave loss 7.8167648179828655
# Finish 996 epoch(es)
# step 997 - loss 7.925106048583984 - moving ave loss 7.827598941042977
# Finish 997 epoch(es)
# step 998 - loss 9.123872756958008 - moving ave loss 7.95722632263448
# Finish 998 epoch(es)
# step 999 - loss 6.633177280426025 - moving ave loss 7.824821418413634
# Finish 999 epoch(es)
# step 1000 - loss 7.990729808807373 - moving ave loss 7.841412257453008
# Checkpoint at step 1000
# Finish 1000 epoch(es)
# CPU times: user 19h 40min 33s, sys: 6h 50min 20s, total: 1d 2h 30min 53s
# Wall time: 5h 6min 35s
